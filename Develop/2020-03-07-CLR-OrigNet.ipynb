# %%
# !python mlip_setup_env.py
# !pip install webdavclient3

# %%
cd code/hw1/
# Out:
# /content/code/hw1

# %%
# %tensorflow_version 2.x

import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Lambda, Dense, Conv2D, Flatten
from tensorflow.keras.layers import MaxPool2D, Dropout, BatchNormalization
from tensorflow.keras.models import Model, clone_model
from tensorflow.keras.optimizers import SGD

from starter_eda_model_funcs import MultiOutputDataGenerator, get_model
from helper import to_one_hot, preview_data_aug
from preprocessing import perform_preprocessing
from flow import generators_from_prep, generator_wrapper, train
from flow import get_lr_test_scheduler, get_pyramid_lr

# further settings
FIG_DIR = 'results/generated_figs/'
plt.rcParams["figure.figsize"] = (10, 4.5) # set higher on 4k monitor
plt.rcParams["savefig.format"] = "pdf"
plt.rcParams["savefig.dpi"] = 400
plt.rcParams["savefig.transparent"] = True
plt.rcParams.update({'font.size': 16})
plt.rcParams["savefig.bbox"] = 'tight'

# %%
from webdav3.client import Client

options = {
 'webdav_hostname': "https://joeranbosma.stackstorage.com/remote.php/webdav",
 'webdav_login':    "",
 'webdav_password':  ""
}
client = Client(options)

# %% [markdown]
# # Cyclical Learning Rate

# %%
datagen_args = dict(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    zca_whitening=False,  # apply ZCA whitening
    rotation_range=8,  # randomly rotate images in the range (degrees, 0 to 180)
    zoom_range = 0.15, # Randomly zoom image 
    width_shift_range=0.15,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.15,  # randomly shift images vertically (fraction of total height)
    horizontal_flip=False,  # randomly flip images
    vertical_flip=False,
    shear_range=8, #Shear Intensity (Shear angle in counter-clockwise direction in degrees)
)

roi_size = 64
pad_size = 5
cross_val_parts = 8 # for 12.5% validation data and 87.5% train data
cross_val_num = 0 # which part (shuffled) from [0, ..., n-1]

preprocess_args = dict(
    image_width=roi_size + pad_size*2,
    image_height=roi_size + pad_size*2,
    padding=pad_size,
    cross_val_num=cross_val_num,
    cross_val_parts=cross_val_parts,
)

data_path = 'Data/'
prep_path = f"Data/prep/prep_{roi_size}_{pad_size}/"

# %% [markdown]
# ## Learning rate test
# Increase the learning rate from 0 to 2 in 20 epochs. This gives a slope of ~0.1 per epoch.
# See result: https://app.wandb.ai/joeranbosma/mlip/runs/tkcpti80?workspace=user-joeranbosma

# %%
name      = f"orignet-clr-test-2_0"
model_path = f'Model/{name}/'
external_path = f'models/{name}/'
lr_scheduler = get_lr_test_scheduler(lr_start=0.001, lr_end=2.0, num=20)

# Model from Starter EDA kernel, but with SGD instead of Adam
model = get_model(img_size=74, optimizer = "SGD")

# %%
# train model
print(f"Start training of {name}...")
model = train(name = name, prep_path=prep_path, data_path=data_path,
                model_path=model_path, datagen_args = datagen_args,
                preprocess_args = preprocess_args, cross_val_parts = cross_val_parts,
                cross_val_num = cross_val_num, epochs=20, lr_scheduler_func=lr_scheduler, 
                webdav_client=client, min_epoch_upload=1, model=model,
                external_path=external_path)
# Out:
# Start training of orignet-clr-test-2_0...
# ['loss', 'out_root_loss', 'out_vowel_loss', 'out_consonant_loss', 'out_root_acc', 'out_vowel_acc', 'out_consonant_acc']
# Converting grapheme_root to one-hot encoding
# Converting vowel_diacritic to one-hot encoding
# Converting consonant_diacritic to one-hot encoding
# Found 175735 validated image filenames.
# Found 25105 validated image filenames.
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/joeranbosma/mlip" target="_blank">https://app.wandb.ai/joeranbosma/mlip</a><br/>
#                 Run page: <a href="https://app.wandb.ai/joeranbosma/mlip/runs/tkcpti80" target="_blank">https://app.wandb.ai/joeranbosma/mlip/runs/tkcpti80</a><br/>
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# 685/686 [============================>.] - ETA: 0s - loss: 3.4628 - out_root_loss: 5.1062 - out_vowel_loss: 2.2854 - out_consonant_loss: 1.3534 - out_root_acc: 0.0195 - out_vowel_acc: 0.1895 - out_consonant_acc: 0.5857WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 534s 778ms/step - loss: 3.4625 - out_root_loss: 5.1060 - out_vowel_loss: 2.2851 - out_consonant_loss: 1.3531 - out_root_acc: 0.0195 - out_vowel_acc: 0.1895 - out_consonant_acc: 0.5857 - val_loss: 3.2245 - val_out_root_loss: 4.8397 - val_out_vowel_loss: 2.0139 - val_out_consonant_loss: 1.2046 - val_out_root_acc: 0.0307 - val_out_vowel_acc: 0.3029 - val_out_consonant_acc: 0.6239
# Saving new best model, with val global accuracy of 0.247050 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.10621052631578948.
# Epoch 2/2
#  10/686 [..............................] - ETA: 8:01 - loss: 3.5297 - out_root_loss: 4.9912 - out_vowel_loss: 2.5648 - out_consonant_loss: 1.5717 - out_root_acc: 0.0258 - out_vowel_acc: 0.1727 - out_consonant_acc: 0.4926Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 2.5266 - out_root_loss: 4.0559 - out_vowel_loss: 1.0925 - out_consonant_loss: 0.9024 - out_root_acc: 0.1019 - out_vowel_acc: 0.6084 - out_consonant_acc: 0.6859WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 527s 768ms/step - loss: 2.5254 - out_root_loss: 4.0539 - out_vowel_loss: 1.0919 - out_consonant_loss: 0.9019 - out_root_acc: 0.1022 - out_vowel_acc: 0.6087 - out_consonant_acc: 0.6861 - val_loss: 2.1049 - val_out_root_loss: 3.3594 - val_out_vowel_loss: 0.9235 - val_out_consonant_loss: 0.7774 - val_out_root_acc: 0.2056 - val_out_vowel_acc: 0.6737 - val_out_consonant_acc: 0.7460
# Saving new best model, with val global accuracy of 0.457619 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.21142105263157895.
# Epoch 3/3
#  10/686 [..............................] - ETA: 8:01 - loss: 2.6170 - out_root_loss: 3.9858 - out_vowel_loss: 1.4295 - out_consonant_loss: 1.0668 - out_root_acc: 0.1168 - out_vowel_acc: 0.5402 - out_consonant_acc: 0.6637Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 1.1911 - out_root_loss: 1.8671 - out_vowel_loss: 0.5692 - out_consonant_loss: 0.4610 - out_root_acc: 0.4861 - out_vowel_acc: 0.8061 - out_consonant_acc: 0.8466WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 525s 766ms/step - loss: 1.1904 - out_root_loss: 1.8659 - out_vowel_loss: 0.5692 - out_consonant_loss: 0.4608 - out_root_acc: 0.4864 - out_vowel_acc: 0.8061 - out_consonant_acc: 0.8467 - val_loss: 0.5588 - val_out_root_loss: 0.8684 - val_out_vowel_loss: 0.2336 - val_out_consonant_loss: 0.2647 - val_out_root_acc: 0.7517 - val_out_vowel_acc: 0.9252 - val_out_consonant_acc: 0.9182
# Saving new best model, with val global accuracy of 0.836515 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.31663157894736843.
# Epoch 4/4
#  10/686 [..............................] - ETA: 8:00 - loss: 1.5423 - out_root_loss: 2.3447 - out_vowel_loss: 0.7569 - out_consonant_loss: 0.7227 - out_root_acc: 0.4320 - out_vowel_acc: 0.7625 - out_consonant_acc: 0.7883Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.5975 - out_root_loss: 0.8942 - out_vowel_loss: 0.3338 - out_consonant_loss: 0.2679 - out_root_acc: 0.7471 - out_vowel_acc: 0.8942 - out_consonant_acc: 0.9153WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 525s 765ms/step - loss: 0.5974 - out_root_loss: 0.8940 - out_vowel_loss: 0.3337 - out_consonant_loss: 0.2679 - out_root_acc: 0.7472 - out_vowel_acc: 0.8943 - out_consonant_acc: 0.9153 - val_loss: 0.3435 - val_out_root_loss: 0.5420 - val_out_vowel_loss: 0.1458 - val_out_consonant_loss: 0.1441 - val_out_root_acc: 0.8475 - val_out_vowel_acc: 0.9575 - val_out_consonant_acc: 0.9553
# Saving new best model, with val global accuracy of 0.901955 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.4218421052631579.
# Epoch 5/5
#  10/686 [..............................] - ETA: 7:59 - loss: 0.5121 - out_root_loss: 0.7378 - out_vowel_loss: 0.3180 - out_consonant_loss: 0.2550 - out_root_acc: 0.8004 - out_vowel_acc: 0.9012 - out_consonant_acc: 0.9187Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.4230 - out_root_loss: 0.6232 - out_vowel_loss: 0.2463 - out_consonant_loss: 0.1992 - out_root_acc: 0.8241 - out_vowel_acc: 0.9253 - out_consonant_acc: 0.9377WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 524s 764ms/step - loss: 0.4229 - out_root_loss: 0.6231 - out_vowel_loss: 0.2462 - out_consonant_loss: 0.1991 - out_root_acc: 0.8241 - out_vowel_acc: 0.9253 - out_consonant_acc: 0.9377 - val_loss: 0.3134 - val_out_root_loss: 0.4974 - val_out_vowel_loss: 0.1304 - val_out_consonant_loss: 0.1286 - val_out_root_acc: 0.8573 - val_out_vowel_acc: 0.9620 - val_out_consonant_acc: 0.9625
# Saving new best model, with val global accuracy of 0.909608 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.5270526315789473.
# Epoch 6/6
#  10/686 [..............................] - ETA: 8:00 - loss: 0.3847 - out_root_loss: 0.5705 - out_vowel_loss: 0.2186 - out_consonant_loss: 0.1792 - out_root_acc: 0.8391 - out_vowel_acc: 0.9395 - out_consonant_acc: 0.9438Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.3534 - out_root_loss: 0.5174 - out_vowel_loss: 0.2083 - out_consonant_loss: 0.1704 - out_root_acc: 0.8554 - out_vowel_acc: 0.9389 - out_consonant_acc: 0.9471WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 524s 764ms/step - loss: 0.3532 - out_root_loss: 0.5171 - out_vowel_loss: 0.2083 - out_consonant_loss: 0.1704 - out_root_acc: 0.8554 - out_vowel_acc: 0.9389 - out_consonant_acc: 0.9471 - val_loss: 0.2160 - val_out_root_loss: 0.3281 - val_out_vowel_loss: 0.0999 - val_out_consonant_loss: 0.1079 - val_out_root_acc: 0.9117 - val_out_vowel_acc: 0.9738 - val_out_consonant_acc: 0.9682
# Saving new best model, with val global accuracy of 0.941227 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.6322631578947369.
# Epoch 7/7
#  10/686 [..............................] - ETA: 7:58 - loss: 0.3056 - out_root_loss: 0.4427 - out_vowel_loss: 0.1796 - out_consonant_loss: 0.1576 - out_root_acc: 0.8777 - out_vowel_acc: 0.9480 - out_consonant_acc: 0.9559Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.3114 - out_root_loss: 0.4547 - out_vowel_loss: 0.1850 - out_consonant_loss: 0.1513 - out_root_acc: 0.8733 - out_vowel_acc: 0.9462 - out_consonant_acc: 0.9533WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 523s 762ms/step - loss: 0.3114 - out_root_loss: 0.4547 - out_vowel_loss: 0.1850 - out_consonant_loss: 0.1513 - out_root_acc: 0.8733 - out_vowel_acc: 0.9462 - out_consonant_acc: 0.9533 - val_loss: 0.1979 - val_out_root_loss: 0.3066 - val_out_vowel_loss: 0.0939 - val_out_consonant_loss: 0.0845 - val_out_root_acc: 0.9138 - val_out_vowel_acc: 0.9743 - val_out_consonant_acc: 0.9744
# Saving new best model, with val global accuracy of 0.944077 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.7374736842105264.
# Epoch 8/8
#  10/686 [..............................] - ETA: 8:01 - loss: 0.3200 - out_root_loss: 0.4618 - out_vowel_loss: 0.1816 - out_consonant_loss: 0.1747 - out_root_acc: 0.8598 - out_vowel_acc: 0.9473 - out_consonant_acc: 0.9488Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.2842 - out_root_loss: 0.4136 - out_vowel_loss: 0.1698 - out_consonant_loss: 0.1397 - out_root_acc: 0.8845 - out_vowel_acc: 0.9514 - out_consonant_acc: 0.9571WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 523s 763ms/step - loss: 0.2840 - out_root_loss: 0.4134 - out_vowel_loss: 0.1696 - out_consonant_loss: 0.1396 - out_root_acc: 0.8846 - out_vowel_acc: 0.9515 - out_consonant_acc: 0.9571 - val_loss: 0.1872 - val_out_root_loss: 0.2899 - val_out_vowel_loss: 0.0854 - val_out_consonant_loss: 0.0835 - val_out_root_acc: 0.9218 - val_out_vowel_acc: 0.9779 - val_out_consonant_acc: 0.9753
# Saving new best model, with val global accuracy of 0.949039 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.8426842105263158.
# Epoch 9/9
#  10/686 [..............................] - ETA: 7:58 - loss: 0.2526 - out_root_loss: 0.3766 - out_vowel_loss: 0.1536 - out_consonant_loss: 0.1036 - out_root_acc: 0.8887 - out_vowel_acc: 0.9547 - out_consonant_acc: 0.9676Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.2612 - out_root_loss: 0.3791 - out_vowel_loss: 0.1585 - out_consonant_loss: 0.1282 - out_root_acc: 0.8937 - out_vowel_acc: 0.9550 - out_consonant_acc: 0.9610WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 523s 762ms/step - loss: 0.2612 - out_root_loss: 0.3791 - out_vowel_loss: 0.1586 - out_consonant_loss: 0.1281 - out_root_acc: 0.8937 - out_vowel_acc: 0.9550 - out_consonant_acc: 0.9610 - val_loss: 0.1953 - val_out_root_loss: 0.3004 - val_out_vowel_loss: 0.0909 - val_out_consonant_loss: 0.0897 - val_out_root_acc: 0.9186 - val_out_vowel_acc: 0.9770 - val_out_consonant_acc: 0.9746
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.9478947368421052.
# Epoch 10/10
# 685/686 [============================>.] - ETA: 0s - loss: 0.2444 - out_root_loss: 0.3537 - out_vowel_loss: 0.1485 - out_consonant_loss: 0.1218 - out_root_acc: 0.9014 - out_vowel_acc: 0.9580 - out_consonant_acc: 0.9634WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 522s 762ms/step - loss: 0.2444 - out_root_loss: 0.3536 - out_vowel_loss: 0.1484 - out_consonant_loss: 0.1217 - out_root_acc: 0.9014 - out_vowel_acc: 0.9580 - out_consonant_acc: 0.9634 - val_loss: 0.1711 - val_out_root_loss: 0.2674 - val_out_vowel_loss: 0.0768 - val_out_consonant_loss: 0.0729 - val_out_root_acc: 0.9308 - val_out_vowel_acc: 0.9806 - val_out_consonant_acc: 0.9798
# Saving new best model, with val global accuracy of 0.955367 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 1.0531052631578945.
# Epoch 11/11
#  10/686 [..............................] - ETA: 7:57 - loss: 0.2110 - out_root_loss: 0.3015 - out_vowel_loss: 0.1350 - out_consonant_loss: 0.1058 - out_root_acc: 0.9113 - out_vowel_acc: 0.9605 - out_consonant_acc: 0.9660Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.2309 - out_root_loss: 0.3338 - out_vowel_loss: 0.1424 - out_consonant_loss: 0.1137 - out_root_acc: 0.9073 - out_vowel_acc: 0.9599 - out_consonant_acc: 0.9657WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 522s 761ms/step - loss: 0.2309 - out_root_loss: 0.3338 - out_vowel_loss: 0.1424 - out_consonant_loss: 0.1136 - out_root_acc: 0.9073 - out_vowel_acc: 0.9599 - out_consonant_acc: 0.9657 - val_loss: 0.1637 - val_out_root_loss: 0.2484 - val_out_vowel_loss: 0.0802 - val_out_consonant_loss: 0.0779 - val_out_root_acc: 0.9339 - val_out_vowel_acc: 0.9805 - val_out_consonant_acc: 0.9778
# Saving new best model, with val global accuracy of 0.956473 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 1.1583157894736842.
# Epoch 12/12
#  10/686 [..............................] - ETA: 7:56 - loss: 0.1983 - out_root_loss: 0.2832 - out_vowel_loss: 0.1307 - out_consonant_loss: 0.0961 - out_root_acc: 0.9223 - out_vowel_acc: 0.9660 - out_consonant_acc: 0.9707Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.2149 - out_root_loss: 0.3095 - out_vowel_loss: 0.1334 - out_consonant_loss: 0.1070 - out_root_acc: 0.9131 - out_vowel_acc: 0.9623 - out_consonant_acc: 0.9678WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 522s 761ms/step - loss: 0.2148 - out_root_loss: 0.3095 - out_vowel_loss: 0.1334 - out_consonant_loss: 0.1069 - out_root_acc: 0.9131 - out_vowel_acc: 0.9623 - out_consonant_acc: 0.9678 - val_loss: 0.1620 - val_out_root_loss: 0.2497 - val_out_vowel_loss: 0.0752 - val_out_consonant_loss: 0.0733 - val_out_root_acc: 0.9344 - val_out_vowel_acc: 0.9816 - val_out_consonant_acc: 0.9787
# Saving new best model, with val global accuracy of 0.957191 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 1.2635263157894736.
# Epoch 13/13
#  10/686 [..............................] - ETA: 7:57 - loss: 0.2009 - out_root_loss: 0.2858 - out_vowel_loss: 0.1168 - out_consonant_loss: 0.1150 - out_root_acc: 0.9176 - out_vowel_acc: 0.9652 - out_consonant_acc: 0.9711Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.2031 - out_root_loss: 0.2919 - out_vowel_loss: 0.1258 - out_consonant_loss: 0.1029 - out_root_acc: 0.9174 - out_vowel_acc: 0.9646 - out_consonant_acc: 0.9691WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 522s 761ms/step - loss: 0.2031 - out_root_loss: 0.2919 - out_vowel_loss: 0.1259 - out_consonant_loss: 0.1029 - out_root_acc: 0.9174 - out_vowel_acc: 0.9646 - out_consonant_acc: 0.9691 - val_loss: 0.1617 - val_out_root_loss: 0.2511 - val_out_vowel_loss: 0.0761 - val_out_consonant_loss: 0.0684 - val_out_root_acc: 0.9348 - val_out_vowel_acc: 0.9811 - val_out_consonant_acc: 0.9812
# Saving new best model, with val global accuracy of 0.957978 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 1.368736842105263.
# Epoch 14/14
#  10/686 [..............................] - ETA: 7:56 - loss: 0.2058 - out_root_loss: 0.2974 - out_vowel_loss: 0.1198 - out_consonant_loss: 0.1084 - out_root_acc: 0.9164 - out_vowel_acc: 0.9664 - out_consonant_acc: 0.9695Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.1925 - out_root_loss: 0.2742 - out_vowel_loss: 0.1222 - out_consonant_loss: 0.0993 - out_root_acc: 0.9225 - out_vowel_acc: 0.9655 - out_consonant_acc: 0.9700WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 523s 762ms/step - loss: 0.1924 - out_root_loss: 0.2741 - out_vowel_loss: 0.1221 - out_consonant_loss: 0.0992 - out_root_acc: 0.9225 - out_vowel_acc: 0.9655 - out_consonant_acc: 0.9700 - val_loss: 0.1424 - val_out_root_loss: 0.2199 - val_out_vowel_loss: 0.0668 - val_out_consonant_loss: 0.0632 - val_out_root_acc: 0.9414 - val_out_vowel_acc: 0.9828 - val_out_consonant_acc: 0.9820
# Saving new best model, with val global accuracy of 0.961804 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 1.4739473684210527.
# Epoch 15/15
#  10/686 [..............................] - ETA: 7:57 - loss: 0.1871 - out_root_loss: 0.2685 - out_vowel_loss: 0.1248 - out_consonant_loss: 0.0863 - out_root_acc: 0.9238 - out_vowel_acc: 0.9664 - out_consonant_acc: 0.9738Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.1836 - out_root_loss: 0.2625 - out_vowel_loss: 0.1159 - out_consonant_loss: 0.0938 - out_root_acc: 0.9258 - out_vowel_acc: 0.9668 - out_consonant_acc: 0.9719WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 522s 761ms/step - loss: 0.1836 - out_root_loss: 0.2623 - out_vowel_loss: 0.1158 - out_consonant_loss: 0.0937 - out_root_acc: 0.9259 - out_vowel_acc: 0.9668 - out_consonant_acc: 0.9719 - val_loss: 0.1391 - val_out_root_loss: 0.2101 - val_out_vowel_loss: 0.0692 - val_out_consonant_loss: 0.0671 - val_out_root_acc: 0.9446 - val_out_vowel_acc: 0.9832 - val_out_consonant_acc: 0.9810
# Saving new best model, with val global accuracy of 0.963200 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 1.579157894736842.
# Epoch 16/16
#  10/686 [..............................] - ETA: 7:57 - loss: 0.1510 - out_root_loss: 0.2163 - out_vowel_loss: 0.0986 - out_consonant_loss: 0.0728 - out_root_acc: 0.9379 - out_vowel_acc: 0.9730 - out_consonant_acc: 0.9785Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.1763 - out_root_loss: 0.2507 - out_vowel_loss: 0.1122 - out_consonant_loss: 0.0914 - out_root_acc: 0.9286 - out_vowel_acc: 0.9685 - out_consonant_acc: 0.9726WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 522s 761ms/step - loss: 0.1762 - out_root_loss: 0.2506 - out_vowel_loss: 0.1123 - out_consonant_loss: 0.0914 - out_root_acc: 0.9286 - out_vowel_acc: 0.9685 - out_consonant_acc: 0.9726 - val_loss: 0.1455 - val_out_root_loss: 0.2237 - val_out_vowel_loss: 0.0683 - val_out_consonant_loss: 0.0663 - val_out_root_acc: 0.9434 - val_out_vowel_acc: 0.9829 - val_out_consonant_acc: 0.9818
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 1.6843684210526315.
# Epoch 17/17
# 685/686 [============================>.] - ETA: 0s - loss: 0.1715 - out_root_loss: 0.2446 - out_vowel_loss: 0.1084 - out_consonant_loss: 0.0882 - out_root_acc: 0.9302 - out_vowel_acc: 0.9694 - out_consonant_acc: 0.9738WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 522s 761ms/step - loss: 0.1715 - out_root_loss: 0.2447 - out_vowel_loss: 0.1083 - out_consonant_loss: 0.0882 - out_root_acc: 0.9302 - out_vowel_acc: 0.9694 - out_consonant_acc: 0.9738 - val_loss: 0.1360 - val_out_root_loss: 0.2075 - val_out_vowel_loss: 0.0693 - val_out_consonant_loss: 0.0599 - val_out_root_acc: 0.9458 - val_out_vowel_acc: 0.9826 - val_out_consonant_acc: 0.9836
# Saving new best model, with val global accuracy of 0.964405 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 1.789578947368421.
# Epoch 18/18
#  10/686 [..............................] - ETA: 7:59 - loss: 0.1614 - out_root_loss: 0.2335 - out_vowel_loss: 0.1093 - out_consonant_loss: 0.0693 - out_root_acc: 0.9328 - out_vowel_acc: 0.9684 - out_consonant_acc: 0.9758Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.1683 - out_root_loss: 0.2394 - out_vowel_loss: 0.1081 - out_consonant_loss: 0.0865 - out_root_acc: 0.9314 - out_vowel_acc: 0.9696 - out_consonant_acc: 0.9738WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 522s 761ms/step - loss: 0.1683 - out_root_loss: 0.2394 - out_vowel_loss: 0.1081 - out_consonant_loss: 0.0864 - out_root_acc: 0.9314 - out_vowel_acc: 0.9696 - out_consonant_acc: 0.9739 - val_loss: 0.1409 - val_out_root_loss: 0.2159 - val_out_vowel_loss: 0.0686 - val_out_consonant_loss: 0.0631 - val_out_root_acc: 0.9429 - val_out_vowel_acc: 0.9830 - val_out_consonant_acc: 0.9828
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 1.8947894736842104.
# Epoch 19/19
# 685/686 [============================>.] - ETA: 0s - loss: 0.1637 - out_root_loss: 0.2317 - out_vowel_loss: 0.1063 - out_consonant_loss: 0.0851 - out_root_acc: 0.9337 - out_vowel_acc: 0.9704 - out_consonant_acc: 0.9743WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 522s 761ms/step - loss: 0.1637 - out_root_loss: 0.2317 - out_vowel_loss: 0.1063 - out_consonant_loss: 0.0852 - out_root_acc: 0.9337 - out_vowel_acc: 0.9704 - out_consonant_acc: 0.9743 - val_loss: 0.1369 - val_out_root_loss: 0.2017 - val_out_vowel_loss: 0.0786 - val_out_consonant_loss: 0.0654 - val_out_root_acc: 0.9484 - val_out_vowel_acc: 0.9815 - val_out_consonant_acc: 0.9837
# Saving new best model, with val global accuracy of 0.965472 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 2.0.
# Epoch 20/20
#  10/686 [..............................] - ETA: 7:56 - loss: 0.1525 - out_root_loss: 0.2198 - out_vowel_loss: 0.0847 - out_consonant_loss: 0.0856 - out_root_acc: 0.9332 - out_vowel_acc: 0.9758 - out_consonant_acc: 0.9754Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.1627 - out_root_loss: 0.2304 - out_vowel_loss: 0.1045 - out_consonant_loss: 0.0854 - out_root_acc: 0.9344 - out_vowel_acc: 0.9710 - out_consonant_acc: 0.9750WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 522s 761ms/step - loss: 0.1626 - out_root_loss: 0.2303 - out_vowel_loss: 0.1045 - out_consonant_loss: 0.0855 - out_root_acc: 0.9344 - out_vowel_acc: 0.9710 - out_consonant_acc: 0.9750 - val_loss: 0.1388 - val_out_root_loss: 0.2097 - val_out_vowel_loss: 0.0746 - val_out_consonant_loss: 0.0613 - val_out_root_acc: 0.9467 - val_out_vowel_acc: 0.9821 - val_out_consonant_acc: 0.9842

# %% [markdown]
# ## Add momentum of 0.75
# See result: https://app.wandb.ai/joeranbosma/mlip/runs/63kk6dfd?workspace=user-joeranbosma

# %%
from tensorflow.keras.optimizers import SGD

name      = f"orignet-clr-test-2_0-momentum"
model_path = f'Model/{name}/'
external_path = f'models/{name}/'
lr_scheduler = get_lr_test_scheduler(lr_start=0.001, lr_end=2.0, num=20)

optimizer = SGD(momentum=0.75)
model = get_model(img_size=74, optimizer=optimizer)

# %%
# train model
print(f"Start training of {name}...")
model = train(name = name, prep_path=prep_path, data_path=data_path,
                model_path=model_path, datagen_args = datagen_args,
                preprocess_args = preprocess_args, cross_val_parts = cross_val_parts,
                cross_val_num = cross_val_num, epochs=20, lr_scheduler_func=lr_scheduler, 
                webdav_client=client, min_epoch_upload=1, model=model,
                external_path=external_path)
# Out:
# Start training of orignet-clr-test-2_0-momentum...
# ['loss', 'out_root_loss', 'out_vowel_loss', 'out_consonant_loss', 'out_root_acc', 'out_vowel_acc', 'out_consonant_acc']
# Converting grapheme_root to one-hot encoding
# Converting vowel_diacritic to one-hot encoding
# Converting consonant_diacritic to one-hot encoding
# Found 175735 validated image filenames.
# Found 25105 validated image filenames.
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/joeranbosma/mlip" target="_blank">https://app.wandb.ai/joeranbosma/mlip</a><br/>
#                 Run page: <a href="https://app.wandb.ai/joeranbosma/mlip/runs/63kk6dfd" target="_blank">https://app.wandb.ai/joeranbosma/mlip/runs/63kk6dfd</a><br/>
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# 685/686 [============================>.] - ETA: 0s - loss: 3.1933 - out_root_loss: 4.8930 - out_vowel_loss: 1.7742 - out_consonant_loss: 1.2130 - out_root_acc: 0.0289 - out_vowel_acc: 0.3845 - out_consonant_acc: 0.6066WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 531s 774ms/step - loss: 3.1930 - out_root_loss: 4.8928 - out_vowel_loss: 1.7736 - out_consonant_loss: 1.2127 - out_root_acc: 0.0289 - out_vowel_acc: 0.3846 - out_consonant_acc: 0.6066 - val_loss: 2.9213 - val_out_root_loss: 4.6702 - val_out_vowel_loss: 1.3197 - val_out_consonant_loss: 1.0251 - val_out_root_acc: 0.0430 - val_out_vowel_acc: 0.5311 - val_out_consonant_acc: 0.6519
# Saving new best model, with val global accuracy of 0.317233 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.10621052631578948.
# Epoch 2/2
#  21/686 [..............................] - ETA: 7:54 - loss: 3.2730 - out_root_loss: 4.8663 - out_vowel_loss: 1.9562 - out_consonant_loss: 1.4032 - out_root_acc: 0.0303 - out_vowel_acc: 0.3307 - out_consonant_acc: 0.5807Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 1.9975 - out_root_loss: 3.1926 - out_vowel_loss: 0.8620 - out_consonant_loss: 0.7428 - out_root_acc: 0.2318 - out_vowel_acc: 0.6992 - out_consonant_acc: 0.7385WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 526s 767ms/step - loss: 1.9960 - out_root_loss: 3.1902 - out_vowel_loss: 0.8616 - out_consonant_loss: 0.7421 - out_root_acc: 0.2322 - out_vowel_acc: 0.6994 - out_consonant_acc: 0.7388 - val_loss: 0.7628 - val_out_root_loss: 1.2240 - val_out_vowel_loss: 0.3120 - val_out_consonant_loss: 0.2911 - val_out_root_acc: 0.6360 - val_out_vowel_acc: 0.9005 - val_out_consonant_acc: 0.9029
# Saving new best model, with val global accuracy of 0.768714 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.21142105263157895.
# Epoch 3/3
#  21/686 [..............................] - ETA: 7:52 - loss: 1.2187 - out_root_loss: 1.9132 - out_vowel_loss: 0.6051 - out_consonant_loss: 0.4433 - out_root_acc: 0.4656 - out_vowel_acc: 0.7946 - out_consonant_acc: 0.8456Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.7731 - out_root_loss: 1.1740 - out_vowel_loss: 0.4212 - out_consonant_loss: 0.3233 - out_root_acc: 0.6689 - out_vowel_acc: 0.8644 - out_consonant_acc: 0.8943WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 525s 765ms/step - loss: 0.7728 - out_root_loss: 1.1735 - out_vowel_loss: 0.4211 - out_consonant_loss: 0.3231 - out_root_acc: 0.6691 - out_vowel_acc: 0.8644 - out_consonant_acc: 0.8944 - val_loss: 0.3804 - val_out_root_loss: 0.5758 - val_out_vowel_loss: 0.2187 - val_out_consonant_loss: 0.1513 - val_out_root_acc: 0.8348 - val_out_vowel_acc: 0.9337 - val_out_consonant_acc: 0.9542
# Saving new best model, with val global accuracy of 0.889250 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.31663157894736843.
# Epoch 4/4
#  21/686 [..............................] - ETA: 7:51 - loss: 0.5583 - out_root_loss: 0.8317 - out_vowel_loss: 0.3287 - out_consonant_loss: 0.2412 - out_root_acc: 0.7623 - out_vowel_acc: 0.8971 - out_consonant_acc: 0.9211Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.4988 - out_root_loss: 0.7402 - out_vowel_loss: 0.2903 - out_consonant_loss: 0.2243 - out_root_acc: 0.7935 - out_vowel_acc: 0.9112 - out_consonant_acc: 0.9293WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 525s 766ms/step - loss: 0.4986 - out_root_loss: 0.7400 - out_vowel_loss: 0.2902 - out_consonant_loss: 0.2243 - out_root_acc: 0.7936 - out_vowel_acc: 0.9112 - out_consonant_acc: 0.9293 - val_loss: 0.2778 - val_out_root_loss: 0.4247 - val_out_vowel_loss: 0.1349 - val_out_consonant_loss: 0.1269 - val_out_root_acc: 0.8861 - val_out_vowel_acc: 0.9613 - val_out_consonant_acc: 0.9635
# Saving new best model, with val global accuracy of 0.924107 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.4218421052631579.
# Epoch 5/5
#  21/686 [..............................] - ETA: 7:51 - loss: 0.4207 - out_root_loss: 0.6273 - out_vowel_loss: 0.2351 - out_consonant_loss: 0.1929 - out_root_acc: 0.8270 - out_vowel_acc: 0.9269 - out_consonant_acc: 0.9416Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.3845 - out_root_loss: 0.5677 - out_vowel_loss: 0.2244 - out_consonant_loss: 0.1783 - out_root_acc: 0.8422 - out_vowel_acc: 0.9342 - out_consonant_acc: 0.9457WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 524s 764ms/step - loss: 0.3845 - out_root_loss: 0.5677 - out_vowel_loss: 0.2242 - out_consonant_loss: 0.1782 - out_root_acc: 0.8422 - out_vowel_acc: 0.9342 - out_consonant_acc: 0.9457 - val_loss: 0.2217 - val_out_root_loss: 0.3370 - val_out_vowel_loss: 0.1107 - val_out_consonant_loss: 0.1022 - val_out_root_acc: 0.9095 - val_out_vowel_acc: 0.9698 - val_out_consonant_acc: 0.9711
# Saving new best model, with val global accuracy of 0.939712 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.5270526315789473.
# Epoch 6/6
#  21/686 [..............................] - ETA: 7:50 - loss: 0.3381 - out_root_loss: 0.4965 - out_vowel_loss: 0.2083 - out_consonant_loss: 0.1510 - out_root_acc: 0.8573 - out_vowel_acc: 0.9429 - out_consonant_acc: 0.9524Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.3231 - out_root_loss: 0.4738 - out_vowel_loss: 0.1919 - out_consonant_loss: 0.1528 - out_root_acc: 0.8687 - out_vowel_acc: 0.9445 - out_consonant_acc: 0.9529WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 525s 765ms/step - loss: 0.3230 - out_root_loss: 0.4736 - out_vowel_loss: 0.1919 - out_consonant_loss: 0.1528 - out_root_acc: 0.8687 - out_vowel_acc: 0.9445 - out_consonant_acc: 0.9529 - val_loss: 0.2130 - val_out_root_loss: 0.3296 - val_out_vowel_loss: 0.1073 - val_out_consonant_loss: 0.0855 - val_out_root_acc: 0.9113 - val_out_vowel_acc: 0.9726 - val_out_consonant_acc: 0.9765
# Saving new best model, with val global accuracy of 0.942652 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.6322631578947369.
# Epoch 7/7
#  21/686 [..............................] - ETA: 7:49 - loss: 0.2899 - out_root_loss: 0.4252 - out_vowel_loss: 0.1711 - out_consonant_loss: 0.1381 - out_root_acc: 0.8798 - out_vowel_acc: 0.9483 - out_consonant_acc: 0.9585Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.2999 - out_root_loss: 0.4397 - out_vowel_loss: 0.1754 - out_consonant_loss: 0.1447 - out_root_acc: 0.8782 - out_vowel_acc: 0.9495 - out_consonant_acc: 0.9565WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 524s 764ms/step - loss: 0.2999 - out_root_loss: 0.4398 - out_vowel_loss: 0.1754 - out_consonant_loss: 0.1447 - out_root_acc: 0.8781 - out_vowel_acc: 0.9495 - out_consonant_acc: 0.9565 - val_loss: 0.1954 - val_out_root_loss: 0.2999 - val_out_vowel_loss: 0.0933 - val_out_consonant_loss: 0.0884 - val_out_root_acc: 0.9201 - val_out_vowel_acc: 0.9751 - val_out_consonant_acc: 0.9754
# Saving new best model, with val global accuracy of 0.947495 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.7374736842105264.
# Epoch 8/8
#  21/686 [..............................] - ETA: 7:50 - loss: 0.2792 - out_root_loss: 0.4092 - out_vowel_loss: 0.1626 - out_consonant_loss: 0.1359 - out_root_acc: 0.8869 - out_vowel_acc: 0.9513 - out_consonant_acc: 0.9557Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.2855 - out_root_loss: 0.4168 - out_vowel_loss: 0.1687 - out_consonant_loss: 0.1396 - out_root_acc: 0.8853 - out_vowel_acc: 0.9519 - out_consonant_acc: 0.9579WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 524s 763ms/step - loss: 0.2853 - out_root_loss: 0.4166 - out_vowel_loss: 0.1686 - out_consonant_loss: 0.1395 - out_root_acc: 0.8854 - out_vowel_acc: 0.9519 - out_consonant_acc: 0.9579 - val_loss: 0.1862 - val_out_root_loss: 0.2888 - val_out_vowel_loss: 0.0851 - val_out_consonant_loss: 0.0820 - val_out_root_acc: 0.9228 - val_out_vowel_acc: 0.9791 - val_out_consonant_acc: 0.9762
# Saving new best model, with val global accuracy of 0.950255 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.8426842105263158.
# Epoch 9/9
#  21/686 [..............................] - ETA: 7:49 - loss: 0.2635 - out_root_loss: 0.3797 - out_vowel_loss: 0.1694 - out_consonant_loss: 0.1255 - out_root_acc: 0.8953 - out_vowel_acc: 0.9531 - out_consonant_acc: 0.9628Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.2795 - out_root_loss: 0.4074 - out_vowel_loss: 0.1693 - out_consonant_loss: 0.1338 - out_root_acc: 0.8888 - out_vowel_acc: 0.9528 - out_consonant_acc: 0.9601WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 523s 763ms/step - loss: 0.2794 - out_root_loss: 0.4072 - out_vowel_loss: 0.1694 - out_consonant_loss: 0.1337 - out_root_acc: 0.8888 - out_vowel_acc: 0.9527 - out_consonant_acc: 0.9601 - val_loss: 0.1909 - val_out_root_loss: 0.2893 - val_out_vowel_loss: 0.0908 - val_out_consonant_loss: 0.0942 - val_out_root_acc: 0.9253 - val_out_vowel_acc: 0.9770 - val_out_consonant_acc: 0.9752
# Saving new best model, with val global accuracy of 0.950524 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.9478947368421052.
# Epoch 10/10
#  21/686 [..............................] - ETA: 7:51 - loss: 0.2617 - out_root_loss: 0.3840 - out_vowel_loss: 0.1504 - out_consonant_loss: 0.1283 - out_root_acc: 0.8968 - out_vowel_acc: 0.9561 - out_consonant_acc: 0.9604Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.2806 - out_root_loss: 0.4091 - out_vowel_loss: 0.1710 - out_consonant_loss: 0.1333 - out_root_acc: 0.8894 - out_vowel_acc: 0.9525 - out_consonant_acc: 0.9600WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 524s 763ms/step - loss: 0.2805 - out_root_loss: 0.4089 - out_vowel_loss: 0.1710 - out_consonant_loss: 0.1333 - out_root_acc: 0.8894 - out_vowel_acc: 0.9525 - out_consonant_acc: 0.9600 - val_loss: 0.1913 - val_out_root_loss: 0.2914 - val_out_vowel_loss: 0.0927 - val_out_consonant_loss: 0.0898 - val_out_root_acc: 0.9283 - val_out_vowel_acc: 0.9781 - val_out_consonant_acc: 0.9757
# Saving new best model, with val global accuracy of 0.952557 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 1.0531052631578945.
# Epoch 11/11
#  21/686 [..............................] - ETA: 7:50 - loss: 0.2660 - out_root_loss: 0.3999 - out_vowel_loss: 0.1496 - out_consonant_loss: 0.1146 - out_root_acc: 0.8940 - out_vowel_acc: 0.9598 - out_consonant_acc: 0.9643Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.2809 - out_root_loss: 0.4077 - out_vowel_loss: 0.1724 - out_consonant_loss: 0.1356 - out_root_acc: 0.8912 - out_vowel_acc: 0.9524 - out_consonant_acc: 0.9597WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 523s 762ms/step - loss: 0.2808 - out_root_loss: 0.4077 - out_vowel_loss: 0.1724 - out_consonant_loss: 0.1355 - out_root_acc: 0.8912 - out_vowel_acc: 0.9524 - out_consonant_acc: 0.9597 - val_loss: 0.1855 - val_out_root_loss: 0.2823 - val_out_vowel_loss: 0.0937 - val_out_consonant_loss: 0.0835 - val_out_root_acc: 0.9249 - val_out_vowel_acc: 0.9771 - val_out_consonant_acc: 0.9769
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 1.1583157894736842.
# Epoch 12/12
# 685/686 [============================>.] - ETA: 0s - loss: 0.2879 - out_root_loss: 0.4181 - out_vowel_loss: 0.1777 - out_consonant_loss: 0.1377 - out_root_acc: 0.8901 - out_vowel_acc: 0.9505 - out_consonant_acc: 0.9598WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 523s 763ms/step - loss: 0.2878 - out_root_loss: 0.4179 - out_vowel_loss: 0.1777 - out_consonant_loss: 0.1376 - out_root_acc: 0.8901 - out_vowel_acc: 0.9505 - out_consonant_acc: 0.9598 - val_loss: 0.2166 - val_out_root_loss: 0.3195 - val_out_vowel_loss: 0.1217 - val_out_consonant_loss: 0.1058 - val_out_root_acc: 0.9218 - val_out_vowel_acc: 0.9705 - val_out_consonant_acc: 0.9725
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 1.2635263157894736.
# Epoch 13/13
# 685/686 [============================>.] - ETA: 0s - loss: 0.3048 - out_root_loss: 0.4417 - out_vowel_loss: 0.1908 - out_consonant_loss: 0.1449 - out_root_acc: 0.8853 - out_vowel_acc: 0.9473 - out_consonant_acc: 0.9574WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 522s 762ms/step - loss: 0.3047 - out_root_loss: 0.4415 - out_vowel_loss: 0.1908 - out_consonant_loss: 0.1450 - out_root_acc: 0.8854 - out_vowel_acc: 0.9473 - out_consonant_acc: 0.9574 - val_loss: 0.2073 - val_out_root_loss: 0.3124 - val_out_vowel_loss: 0.1024 - val_out_consonant_loss: 0.1021 - val_out_root_acc: 0.9255 - val_out_vowel_acc: 0.9744 - val_out_consonant_acc: 0.9753
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 1.368736842105263.
# Epoch 14/14
# 685/686 [============================>.] - ETA: 0s - loss: 0.3326 - out_root_loss: 0.4821 - out_vowel_loss: 0.2096 - out_consonant_loss: 0.1565 - out_root_acc: 0.8775 - out_vowel_acc: 0.9423 - out_consonant_acc: 0.9543WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 523s 763ms/step - loss: 0.3325 - out_root_loss: 0.4819 - out_vowel_loss: 0.2096 - out_consonant_loss: 0.1565 - out_root_acc: 0.8775 - out_vowel_acc: 0.9424 - out_consonant_acc: 0.9543 - val_loss: 0.2051 - val_out_root_loss: 0.3055 - val_out_vowel_loss: 0.1119 - val_out_consonant_loss: 0.0977 - val_out_root_acc: 0.9287 - val_out_vowel_acc: 0.9736 - val_out_consonant_acc: 0.9719
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 1.4739473684210527.
# Epoch 15/15
# 685/686 [============================>.] - ETA: 0s - loss: 0.4057 - out_root_loss: 0.5849 - out_vowel_loss: 0.2651 - out_consonant_loss: 0.1878 - out_root_acc: 0.8577 - out_vowel_acc: 0.9282 - out_consonant_acc: 0.9468WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 523s 762ms/step - loss: 0.4056 - out_root_loss: 0.5849 - out_vowel_loss: 0.2650 - out_consonant_loss: 0.1877 - out_root_acc: 0.8577 - out_vowel_acc: 0.9282 - out_consonant_acc: 0.9468 - val_loss: 0.2694 - val_out_root_loss: 0.4158 - val_out_vowel_loss: 0.1311 - val_out_consonant_loss: 0.1151 - val_out_root_acc: 0.9072 - val_out_vowel_acc: 0.9674 - val_out_consonant_acc: 0.9694
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 1.579157894736842.
# Epoch 16/16
# 685/686 [============================>.] - ETA: 0s - loss: 1.0809 - out_root_loss: 1.5427 - out_vowel_loss: 0.7618 - out_consonant_loss: 0.4763 - out_root_acc: 0.6861 - out_vowel_acc: 0.7940 - out_consonant_acc: 0.8748WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 522s 761ms/step - loss: 1.0839 - out_root_loss: 1.5473 - out_vowel_loss: 0.7638 - out_consonant_loss: 0.4773 - out_root_acc: 0.6852 - out_vowel_acc: 0.7931 - out_consonant_acc: 0.8745 - val_loss: 3.1942 - val_out_root_loss: 4.7225 - val_out_vowel_loss: 2.1321 - val_out_consonant_loss: 1.1997 - val_out_root_acc: 0.0270 - val_out_vowel_acc: 0.2060 - val_out_consonant_acc: 0.6236
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 1.6843684210526315.
# Epoch 17/17
# 685/686 [============================>.] - ETA: 0s - loss: 3.1794 - out_root_loss: 4.6960 - out_vowel_loss: 2.1288 - out_consonant_loss: 1.1967 - out_root_acc: 0.0276 - out_vowel_acc: 0.2048 - out_consonant_acc: 0.6236WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 510s 744ms/step - loss: 3.1793 - out_root_loss: 4.6959 - out_vowel_loss: 2.1288 - out_consonant_loss: 1.1966 - out_root_acc: 0.0277 - out_vowel_acc: 0.2047 - out_consonant_acc: 0.6236 - val_loss: 3.1780 - val_out_root_loss: 4.6916 - val_out_vowel_loss: 2.1332 - val_out_consonant_loss: 1.1959 - val_out_root_acc: 0.0256 - val_out_vowel_acc: 0.2060 - val_out_consonant_acc: 0.6236
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 1.789578947368421.
# Epoch 18/18
# 685/686 [============================>.] - ETA: 0s - loss: 3.1785 - out_root_loss: 4.6941 - out_vowel_loss: 2.1286 - out_consonant_loss: 1.1972 - out_root_acc: 0.0269 - out_vowel_acc: 0.2063 - out_consonant_acc: 0.6236WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 510s 744ms/step - loss: 3.1785 - out_root_loss: 4.6942 - out_vowel_loss: 2.1286 - out_consonant_loss: 1.1971 - out_root_acc: 0.0269 - out_vowel_acc: 0.2063 - out_consonant_acc: 0.6236 - val_loss: 3.1780 - val_out_root_loss: 4.6914 - val_out_vowel_loss: 2.1328 - val_out_consonant_loss: 1.1965 - val_out_root_acc: 0.0277 - val_out_vowel_acc: 0.2060 - val_out_consonant_acc: 0.6236
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 1.8947894736842104.
# Epoch 19/19
# 685/686 [============================>.] - ETA: 0s - loss: 3.1784 - out_root_loss: 4.6941 - out_vowel_loss: 2.1293 - out_consonant_loss: 1.1961 - out_root_acc: 0.0279 - out_vowel_acc: 0.2041 - out_consonant_acc: 0.6242WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 510s 743ms/step - loss: 3.1784 - out_root_loss: 4.6940 - out_vowel_loss: 2.1293 - out_consonant_loss: 1.1962 - out_root_acc: 0.0279 - out_vowel_acc: 0.2040 - out_consonant_acc: 0.6242 - val_loss: 3.1782 - val_out_root_loss: 4.6920 - val_out_vowel_loss: 2.1321 - val_out_consonant_loss: 1.1965 - val_out_root_acc: 0.0286 - val_out_vowel_acc: 0.2060 - val_out_consonant_acc: 0.6236
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 2.0.
# Epoch 20/20
# 685/686 [============================>.] - ETA: 0s - loss: 3.1782 - out_root_loss: 4.6927 - out_vowel_loss: 2.1290 - out_consonant_loss: 1.1981 - out_root_acc: 0.0278 - out_vowel_acc: 0.2046 - out_consonant_acc: 0.6234WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 510s 744ms/step - loss: 3.1782 - out_root_loss: 4.6927 - out_vowel_loss: 2.1291 - out_consonant_loss: 1.1982 - out_root_acc: 0.0278 - out_vowel_acc: 0.2045 - out_consonant_acc: 0.6233 - val_loss: 3.1780 - val_out_root_loss: 4.6920 - val_out_vowel_loss: 2.1320 - val_out_consonant_loss: 1.1961 - val_out_root_acc: 0.0273 - val_out_vowel_acc: 0.2060 - val_out_consonant_acc: 0.6236

# %% [markdown]
# ## Change momentum cyclical
# And use Nesterov.

# %%
from tensorflow.keras.optimizers import SGD

name      = f"orignet-clr-test-2_0-momentum"
model_path = f'Model/{name}/'
external_path = f'models/{name}/'
lr_scheduler = get_lr_test_scheduler(lr_start=0.001, lr_end=2.0, num=20)

optimizer = SGD(momentum=0.75, nesterov=True)
model = get_model(img_size=74, optimizer=optimizer)
# Out:
# 1

# %% [markdown]
# ...implementation...

# %% [markdown]
# ## Employ CLR
# From the run with momentum followed that the training broke down near a learning rate of 1.4 in 14 epochs, see [here](https://app.wandb.ai/joeranbosma/mlip/runs/63kk6dfd?workspace=user-joeranbosma). Based on that, the run below increases the learning rate until 1.2 (to be a bit safer), with the same slope, so in 12 epochs (kind of the minimum I guess). To do this, the a pyramid learning rate scheduler is employed with 12+12+6 epochs = 30.
#
# Result: https://app.wandb.ai/joeranbosma/mlip/runs/qfxkomde

# %%
epochs = 30

name      = f"orignet-clr-1_2-momentum-0_75"
model_path = f'Model/{name}/'
external_path = f'models/{name}/'
lr_scheduler = get_pyramid_lr(lr_start=0.1, lr_max=1.2, n_epoch=epochs, n_epochs_end=6)

optimizer = SGD(momentum=0.75, nesterov=True)
model = get_model(img_size=74, optimizer=optimizer)

# %%
# train model
print(f"Start training of {name}...")
model = train(name = name, prep_path=prep_path, data_path=data_path,
                model_path=model_path, datagen_args = datagen_args,
                preprocess_args = preprocess_args, cross_val_parts = cross_val_parts,
                cross_val_num = cross_val_num, epochs=epochs, lr_scheduler_func=lr_scheduler, 
                webdav_client=client, min_epoch_upload=1, model=model,
                external_path=external_path)
# Out:
# Start training of orignet-clr-1_2-momentum-0_75...
# Converting grapheme_root to one-hot encoding
# Converting vowel_diacritic to one-hot encoding
# Converting consonant_diacritic to one-hot encoding
# Found 175735 validated image filenames.
# Found 25105 validated image filenames.
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/joeranbosma/mlip" target="_blank">https://app.wandb.ai/joeranbosma/mlip</a><br/>
#                 Run page: <a href="https://app.wandb.ai/joeranbosma/mlip/runs/3lwrmr6n" target="_blank">https://app.wandb.ai/joeranbosma/mlip/runs/3lwrmr6n</a><br/>
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.1.
# 685/686 [============================>.] - ETA: 0s - loss: 2.6244 - out_root_loss: 4.1495 - out_vowel_loss: 1.2365 - out_consonant_loss: 0.9620 - out_root_acc: 0.0747 - out_vowel_acc: 0.5449 - out_consonant_acc: 0.6569WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 555s 810ms/step - loss: 2.6236 - out_root_loss: 4.1486 - out_vowel_loss: 1.2358 - out_consonant_loss: 0.9613 - out_root_acc: 0.0747 - out_vowel_acc: 0.5450 - out_consonant_acc: 0.6570 - val_loss: 3.0479 - val_out_root_loss: 5.0572 - val_out_vowel_loss: 1.0716 - val_out_consonant_loss: 1.0055 - val_out_root_acc: 0.0785 - val_out_vowel_acc: 0.6213 - val_out_consonant_acc: 0.7030
# Saving new best model, with val global accuracy of 0.370336 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.2.
# Epoch 2/2
#  26/686 [>.............................] - ETA: 8:13 - loss: 2.3375 - out_root_loss: 3.6886 - out_vowel_loss: 1.0413 - out_consonant_loss: 0.9316 - out_root_acc: 0.1190 - out_vowel_acc: 0.6211 - out_consonant_acc: 0.6686Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 1.4413 - out_root_loss: 2.3047 - out_vowel_loss: 0.6369 - out_consonant_loss: 0.5190 - out_root_acc: 0.3803 - out_vowel_acc: 0.7802 - out_consonant_acc: 0.8216WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 554s 808ms/step - loss: 1.4404 - out_root_loss: 2.3032 - out_vowel_loss: 0.6366 - out_consonant_loss: 0.5187 - out_root_acc: 0.3806 - out_vowel_acc: 0.7803 - out_consonant_acc: 0.8217 - val_loss: 0.7789 - val_out_root_loss: 1.2796 - val_out_vowel_loss: 0.2884 - val_out_consonant_loss: 0.2680 - val_out_root_acc: 0.6388 - val_out_vowel_acc: 0.9064 - val_out_consonant_acc: 0.9095
# Saving new best model, with val global accuracy of 0.773069 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.3.
# Epoch 3/3
#  26/686 [>.............................] - ETA: 8:12 - loss: 0.9696 - out_root_loss: 1.5229 - out_vowel_loss: 0.4740 - out_consonant_loss: 0.3584 - out_root_acc: 0.5724 - out_vowel_acc: 0.8492 - out_consonant_acc: 0.8879Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.7227 - out_root_loss: 1.1101 - out_vowel_loss: 0.3774 - out_consonant_loss: 0.2934 - out_root_acc: 0.6857 - out_vowel_acc: 0.8809 - out_consonant_acc: 0.9068WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 554s 807ms/step - loss: 0.7225 - out_root_loss: 1.1097 - out_vowel_loss: 0.3775 - out_consonant_loss: 0.2933 - out_root_acc: 0.6859 - out_vowel_acc: 0.8810 - out_consonant_acc: 0.9069 - val_loss: 0.4346 - val_out_root_loss: 0.7019 - val_out_vowel_loss: 0.1710 - val_out_consonant_loss: 0.1633 - val_out_root_acc: 0.7994 - val_out_vowel_acc: 0.9493 - val_out_consonant_acc: 0.9503
# Saving new best model, with val global accuracy of 0.874302 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.4.
# Epoch 4/4
#  26/686 [>.............................] - ETA: 8:13 - loss: 0.5677 - out_root_loss: 0.8642 - out_vowel_loss: 0.3110 - out_consonant_loss: 0.2317 - out_root_acc: 0.7553 - out_vowel_acc: 0.9049 - out_consonant_acc: 0.9270Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.4840 - out_root_loss: 0.7310 - out_vowel_loss: 0.2634 - out_consonant_loss: 0.2107 - out_root_acc: 0.7946 - out_vowel_acc: 0.9205 - out_consonant_acc: 0.9347WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 553s 807ms/step - loss: 0.4839 - out_root_loss: 0.7308 - out_vowel_loss: 0.2633 - out_consonant_loss: 0.2107 - out_root_acc: 0.7947 - out_vowel_acc: 0.9205 - out_consonant_acc: 0.9347 - val_loss: 0.2711 - val_out_root_loss: 0.4271 - val_out_vowel_loss: 0.1254 - val_out_consonant_loss: 0.1049 - val_out_root_acc: 0.8792 - val_out_vowel_acc: 0.9654 - val_out_consonant_acc: 0.9698
# Saving new best model, with val global accuracy of 0.923280 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.5.
# Epoch 5/5
# Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.3873 - out_root_loss: 0.5779 - out_vowel_loss: 0.2163 - out_consonant_loss: 0.1773 - out_root_acc: 0.8380 - out_vowel_acc: 0.9364 - out_consonant_acc: 0.9447WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 552s 805ms/step - loss: 0.3874 - out_root_loss: 0.5781 - out_vowel_loss: 0.2161 - out_consonant_loss: 0.1772 - out_root_acc: 0.8380 - out_vowel_acc: 0.9365 - out_consonant_acc: 0.9447 - val_loss: 0.2420 - val_out_root_loss: 0.3738 - val_out_vowel_loss: 0.1111 - val_out_consonant_loss: 0.1091 - val_out_root_acc: 0.8959 - val_out_vowel_acc: 0.9705 - val_out_consonant_acc: 0.9675
# Saving new best model, with val global accuracy of 0.932278 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.6.
# Epoch 6/6
#  26/686 [>.............................] - ETA: 8:13 - loss: 0.3595 - out_root_loss: 0.5417 - out_vowel_loss: 0.1974 - out_consonant_loss: 0.1571 - out_root_acc: 0.8441 - out_vowel_acc: 0.9408 - out_consonant_acc: 0.9497Upload finished.
# 232/686 [=========>....................] - ETA: 5:38 - loss: 0.3649 - out_root_loss: 0.5431 - out_vowel_loss: 0.2058 - out_consonant_loss: 0.1677 - out_root_acc: 0.8464 - out_vowel_acc: 0.9401 - out_consonant_acc: 0.9488WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 232/686 [=========>....................] - ETA: 6:19 - loss: 0.3649 - out_root_loss: 0.5431 - out_vowel_loss: 0.2058 - out_consonant_loss: 0.1677 - out_root_acc: 0.8464 - out_vowel_acc: 0.9401 - out_consonant_acc: 0.9488
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-a719649e8526> in <module>()
#       5                 cross_val_num = cross_val_num, epochs=epochs, lr_scheduler_func=lr_scheduler,
#       6                 webdav_client=client, min_epoch_upload=1, model=model,
# ----> 7                 external_path=external_path)
#
# /content/code/hw1/flow.py in train(datagen_args, preprocess_args, name, batch_size, epochs, model, cross_val_num, cross_val_parts, lr_scheduler_func, show_data_aug, webdav_client, min_epoch_upload, external_path, data_path, prep_path, model_path)
#     233                       initial_epoch=ep - 1, epochs=ep, steps_per_epoch=train_generator.n // train_generator.batch_size,
#     234                       validation_steps=val_generator.n // val_generator.batch_size,
# --> 235                       callbacks=callbacks)
#     236
#     237         # check global validation accuracy
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/wandb/keras/__init__.py in new_v2(*args, **kwargs)
#     110             for cbk in cbks:
#     111                 set_wandb_attrs(cbk, val_data)
# --> 112         return old_v2(*args, **kwargs)
#     113
#     114     training_arrays.orig_fit_loop = old_arrays
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     340                 mode=ModeKeys.TRAIN,
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     344
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     126         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#     130         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/training_v2_utils.py in execution_function(input_fn)
#      96     # `numpy` translates Tensors to values in Eager mode.
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#     100   return execution_function
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     566
#     567   return pack_sequence_as(
# --> 568       structure[0], [func(*x) for x in entries],
#     569       expand_composites=expand_composites)
#     570
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/util/nest.py in <listcomp>(.0)
#     566
#     567   return pack_sequence_as(
# --> 568       structure[0], [func(*x) for x in entries],
#     569       expand_composites=expand_composites)
#     570
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/training_v2_utils.py in _non_none_constant_value(v)
#     128
#     129 def _non_none_constant_value(v):
# --> 130   constant_value = tensor_util.constant_value(v)
#     131   return constant_value if constant_value is not None else v
#     132
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/framework/tensor_util.py in constant_value(tensor, partial)
#     820   """
#     821   if isinstance(tensor, ops.EagerTensor):
# --> 822     return tensor.numpy()
#     823   if not is_tensor(tensor):
#     824     return tensor
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/framework/ops.py in numpy(self)
#     940     """
#     941     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# --> 942     maybe_arr = self._numpy()  # pylint: disable=protected-access
#     943     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#     944
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/framework/ops.py in _numpy(self)
#     906     # pylint: disable=protected-access
#     907     try:
# --> 908       return self._numpy_internal()
#     909     except core._NotOkStatusException as e:
#     910       six.raise_from(core._status_to_exception(e.code, e.message), None)
#
# KeyboardInterrupt:
# 404 response executing GraphQL.
# {"errors":[{"message":"run joeranbosma/mlip/nkh4tccp not found during upsertBucket","path":["upsertBucket"]}],"data":{"upsertBucket":null}}
# wandb: ERROR Error while calling W&B API: run joeranbosma/mlip/nkh4tccp not found during upsertBucket (<Response [404]>)
# Error in callback <function _init_jupyter.<locals>.cleanup at 0x7f453d9dea60> (for post_run_cell):
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/wandb/retry.py in __call__(self, *args, **kwargs)
#      94             try:
# ---> 95                 result = self._call_fn(*args, **kwargs)
#      96                 if not first:
#
# /usr/local/lib/python3.6/dist-packages/wandb/apis/internal.py in execute(self, *args, **kwargs)
#     115             self.display_gorilla_error_if_found(res)
# --> 116             six.reraise(*sys.exc_info())
#     117
#
# /usr/local/lib/python3.6/dist-packages/six.py in reraise(tp, value, tb)
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#
# /usr/local/lib/python3.6/dist-packages/wandb/apis/internal.py in execute(self, *args, **kwargs)
#     109         try:
# --> 110             return self.client.execute(*args, **kwargs)
#     111         except requests.exceptions.HTTPError as err:
#
# /usr/local/lib/python3.6/dist-packages/gql/client.py in execute(self, document, *args, **kwargs)
#      51
# ---> 52         result = self._get_result(document, *args, **kwargs)
#      53         if result.errors:
#
# /usr/local/lib/python3.6/dist-packages/gql/client.py in _get_result(self, document, *args, **kwargs)
#      59         if not self.retries:
# ---> 60             return self.transport.execute(document, *args, **kwargs)
#      61
#
# /usr/local/lib/python3.6/dist-packages/gql/transport/requests.py in execute(self, document, variable_values, timeout)
#      38         request = requests.post(self.url, **post_args)
# ---> 39         request.raise_for_status()
#      40
#
# /usr/local/lib/python3.6/dist-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: Not Found for url: https://api.wandb.ai/graphql
#
# During handling of the above exception, another exception occurred:
#
# CommError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/wandb/apis/__init__.py in wrapper(*args, **kwargs)
#      59         try:
# ---> 60             return func(*args, **kwargs)
#      61         except requests.HTTPError as err:
#
# /usr/local/lib/python3.6/dist-packages/wandb/apis/internal.py in upsert_run(self, id, name, project, host, group, tags, config, description, entity, state, display_name, notes, repo, job_type, program_path, commit, sweep_name, summary_metrics, num_retries)
#     785         response = self.gql(
# --> 786             mutation, variable_values=variable_values, **kwargs)
#     787
#
# /usr/local/lib/python3.6/dist-packages/wandb/retry.py in __call__(self, *args, **kwargs)
#     101                 # if the secondary check fails, re-raise
# --> 102                 if not check_retry_fn(e):
#     103                     raise
#
# /usr/local/lib/python3.6/dist-packages/wandb/util.py in no_retry_auth(e)
#     527     elif wandb.run:
# --> 528         raise CommError("Permission denied to access {}".format(wandb.run.path))
#     529     else:
#
# CommError: Permission denied to access joeranbosma/mlip/3lwrmr6n
#
# During handling of the above exception, another exception occurred:
#
# CommError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/wandb/__init__.py in cleanup()
#     484         # shutdown async logger because _user_process_finished isn't called in jupyter
#     485         shutdown_async_log_thread()
# --> 486         run._stop_jupyter_agent()
#     487     ipython.events.register('post_run_cell', cleanup)
#     488
#
# /usr/local/lib/python3.6/dist-packages/wandb/wandb_run.py in _stop_jupyter_agent(self)
#     180
#     181     def _stop_jupyter_agent(self):
# --> 182         self._jupyter_agent.stop()
#     183
#     184     def send_message(self, options):
#
# /usr/local/lib/python3.6/dist-packages/wandb/jupyter.py in stop(self)
#     134         if not self.paused:
#     135             self.rm.unmirror_stdout_stderr()
# --> 136             self.rm.shutdown()
#     137             wandb.run.close_files()
#     138             self.paused = True
#
# /usr/local/lib/python3.6/dist-packages/wandb/run_manager.py in shutdown(self, exitcode)
#    1079         if self._cloud:
#    1080             logger.info("stopping streaming files and file change observer")
# -> 1081             self._end_file_syncing(exitcode)
#    1082
#    1083         self._run.history.close()
#
# /usr/local/lib/python3.6/dist-packages/wandb/run_manager.py in _end_file_syncing(self, exitcode)
#     664         # TODO: there was a case where _file_event_handlers was getting modified in the loop.
#     665         for handler in list(self._file_event_handlers.values()):
# --> 666             handler.finish()
#     667
#     668         self._file_pusher.finish()
#
# /usr/local/lib/python3.6/dist-packages/wandb/run_manager.py in finish(self)
#     280             self._thread = None
#     281
# --> 282         self._update()
#     283
#     284
#
# /usr/local/lib/python3.6/dist-packages/wandb/run_manager.py in _update(self)
#     271         # TODO(adrian): ensure the file content will exactly match Bucket.config
#     272         # ie. push the file content as a string
# --> 273         self._api.upsert_run(id=self._run.storage_id, config=config_dict)
#     274         self._file_pusher.file_changed(self.save_name, self.file_path)
#     275         self._last_sent = time.time()
#
# /usr/local/lib/python3.6/dist-packages/wandb/apis/__init__.py in wrapper(*args, **kwargs)
#      90             else:
#      91                 six.reraise(CommError, CommError(
# ---> 92                     message, err), sys.exc_info()[2])
#      93
#      94     return wrapper
#
# /usr/local/lib/python3.6/dist-packages/six.py in reraise(tp, value, tb)
#     690                 value = tp()
#     691             if value.__traceback__ is not tb:
# --> 692                 raise value.with_traceback(tb)
#     693             raise value
#     694         finally:
#
# /usr/local/lib/python3.6/dist-packages/wandb/apis/__init__.py in wrapper(*args, **kwargs)
#      58         message = "Whoa, you found a bug."
#      59         try:
# ---> 60             return func(*args, **kwargs)
#      61         except requests.HTTPError as err:
#      62             raise CommError(err.response, err)
#
# /usr/local/lib/python3.6/dist-packages/wandb/apis/internal.py in upsert_run(self, id, name, project, host, group, tags, config, description, entity, state, display_name, notes, repo, job_type, program_path, commit, sweep_name, summary_metrics, num_retries)
#     784
#     785         response = self.gql(
# --> 786             mutation, variable_values=variable_values, **kwargs)
#     787
#     788         run = response['upsertBucket']['bucket']
#
# /usr/local/lib/python3.6/dist-packages/wandb/retry.py in __call__(self, *args, **kwargs)
#     100             except self._retryable_exceptions as e:
#     101                 # if the secondary check fails, re-raise
# --> 102                 if not check_retry_fn(e):
#     103                     raise
#     104                 if (datetime.datetime.now() - start_time >= retry_timedelta
#
# /usr/local/lib/python3.6/dist-packages/wandb/util.py in no_retry_auth(e)
#     526         raise CommError("Invalid or missing api_key.  Run wandb login" + extra)
#     527     elif wandb.run:
# --> 528         raise CommError("Permission denied to access {}".format(wandb.run.path))
#     529     else:
#     530         raise CommError("Permission denied, ask the project owner to grant you access")
#
# CommError: Permission denied to access joeranbosma/mlip/3lwrmr6n
