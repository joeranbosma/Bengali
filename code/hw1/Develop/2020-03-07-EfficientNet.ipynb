# %%
# !python mlip_setup_env.py
# !pip install webdavclient3
# !pip install efficientnet

# %%
cd code/hw1/
# Out:
# /content/code/hw1

# %%
# %tensorflow_version 2.x

import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Lambda, Dense, Conv2D, Flatten
from tensorflow.keras.layers import MaxPool2D, Dropout, BatchNormalization
from tensorflow.keras.models import Model, clone_model
from tensorflow.keras.optimizers import SGD
import efficientnet.tfkeras as efn

from starter_eda_model_funcs import MultiOutputDataGenerator, get_model
from helper import to_one_hot, preview_data_aug
from preprocessing import perform_preprocessing
from flow import generators_from_prep, generator_wrapper, train
from flow import get_lr_test_scheduler, get_pyramid_lr

# further settings
FIG_DIR = 'results/generated_figs/'
plt.rcParams["figure.figsize"] = (10, 4.5) # set higher on 4k monitor
plt.rcParams["savefig.format"] = "pdf"
plt.rcParams["savefig.dpi"] = 400
plt.rcParams["savefig.transparent"] = True
plt.rcParams.update({'font.size': 16})
plt.rcParams["savefig.bbox"] = 'tight'
# Out:
# TensorFlow 2.x selected.

# %%
from webdav3.client import Client

options = {
 'webdav_hostname': "https://joeranbosma.stackstorage.com/remote.php/webdav",
 'webdav_login':    "MLiP",
 'webdav_password':  "***REMOVED***"
}
client = Client(options)

# %% [markdown]
# # EfficientNet
# Adapted from https://www.kaggle.com/rsmits/keras-efficientnet-b3-training-inference

# %%
datagen_args = dict(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    zca_whitening=False,  # apply ZCA whitening
    rotation_range=8,  # randomly rotate images in the range (degrees, 0 to 180)
    zoom_range = 0.15, # Randomly zoom image 
    width_shift_range=0.15,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.15,  # randomly shift images vertically (fraction of total height)
    horizontal_flip=False,  # randomly flip images
    vertical_flip=False,
    shear_range=8, #Shear Intensity (Shear angle in counter-clockwise direction in degrees)
)

roi_size = 64
pad_size = 5
cross_val_parts = 8 # for 12.5% validation data and 87.5% train data
cross_val_num = 0 # which part (shuffled) from [0, ..., n-1]

preprocess_args = dict(
    image_width=roi_size + pad_size*2,
    image_height=roi_size + pad_size*2,
    padding=pad_size,
    cross_val_num=cross_val_num,
    cross_val_parts=cross_val_parts,
)

data_path = 'Data/'
prep_path = f"Data/prep/prep_{roi_size}_{pad_size}/"

# %% [markdown]
# ## Model implementation

# %%
import tensorflow as tf
# Generalized mean pool - GeM
gm_exp = tf.Variable(3.0, dtype = tf.float32)
def generalized_mean_pool_2d(X):
    pool = (tf.reduce_mean(tf.abs(X**(gm_exp)), 
                        axis = [1, 2], 
                        keepdims = False) + 1.e-7)**(1./gm_exp)
    return pool

# %%
# Create Model
def create_model_eff(input_shape, effnet='B0', optimizer='Adam', loss_weights=[0.4, 0.3, 0.3]):
    # Input Layer
    inp = Input(shape = input_shape)
    
    # Create and Compile Model and show Summary
    kwargs = dict(weights = None, include_top = False, input_tensor = inp, pooling = None, classes = None)
    if effnet == 'B0':
        x_model = efn.EfficientNetB0(**kwargs)
    elif effnet == 'B1':
        x_model = efn.EfficientNetB1(**kwargs)
    elif effnet == 'B2':
        x_model = efn.EfficientNetB2(**kwargs)
    elif effnet == 'B3':
        x_model = efn.EfficientNetB3(**kwargs)
    elif effnet == 'B4':
        x_model = efn.EfficientNetB4(**kwargs)
    elif effnet == 'B5':
        x_model = efn.EfficientNetB5(**kwargs)
    elif effnet == 'B6':
        x_model = efn.EfficientNetB6(**kwargs)
        
    
    # UnFreeze all layers
    for layer in x_model.layers:
        layer.trainable = True
    
    # GeM
    lambda_layer = Lambda(generalized_mean_pool_2d)
    lambda_layer.trainable_weights.extend([gm_exp])
    x = lambda_layer(x_model.output)
    
    # multi output
    grapheme_root = Dense(168, activation = 'softmax', name = 'out_root')(x)
    vowel_diacritic = Dense(11, activation = 'softmax', name = 'out_vowel')(x)
    consonant_diacritic = Dense(7, activation = 'softmax', name = 'out_consonant')(x)

    # model
    model = Model(inputs = x_model.input, outputs = [grapheme_root, vowel_diacritic, consonant_diacritic])

    # compile
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['acc'],
                loss_weights=loss_weights)

    return model

# %%
model = create_model_eff(input_shape=(74, 74, 1))
# Out:
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (lambda), but
# are not present in its tracked objects:
#   <tf.Variable 'Variable:0' shape=() dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 74, 74, 1)]  0
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 37, 37, 32)   288         input_1[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 37, 37, 32)   128         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 37, 37, 32)   0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 37, 37, 32)   288         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 37, 37, 32)   128         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 37, 37, 32)   0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 32)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 37, 37, 32)   0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 37, 37, 16)   512         block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 37, 37, 16)   64          block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 37, 37, 96)   1536        block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 37, 37, 96)   384         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 37, 37, 96)   0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 19, 19, 96)   864         block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 19, 19, 96)   384         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 19, 19, 96)   0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 96)           0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 96)     0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 4)      388         block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 96)     480         block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 19, 19, 96)   0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 19, 19, 24)   2304        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 19, 19, 24)   96          block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 19, 19, 144)  3456        block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 19, 19, 144)  576         block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 19, 19, 144)  0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 19, 19, 144)  1296        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 19, 19, 144)  576         block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 19, 19, 144)  0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 144)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 19, 19, 144)  0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 19, 19, 24)   3456        block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 19, 19, 24)   96          block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (FixedDropout)     (None, 19, 19, 24)   0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 19, 19, 24)   0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 19, 19, 144)  3456        block2b_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 19, 19, 144)  576         block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 19, 19, 144)  0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 10, 10, 144)  3600        block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 10, 10, 144)  576         block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 10, 10, 144)  0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 144)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 144)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 10, 10, 144)  0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 10, 10, 40)   5760        block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 10, 10, 40)   160         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 10, 10, 240)  9600        block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 10, 10, 240)  960         block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 10, 10, 240)  0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 10, 10, 240)  6000        block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 10, 10, 240)  960         block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 10, 10, 240)  0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 240)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 240)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 10, 10, 240)  0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 10, 10, 40)   9600        block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 10, 10, 40)   160         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (FixedDropout)     (None, 10, 10, 40)   0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 10, 10, 40)   0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4a_expand_conv (Conv2D)    (None, 10, 10, 240)  9600        block3b_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, 10, 10, 240)  960         block4a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, 10, 10, 240)  0           block4a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv (DepthwiseConv2D (None, 5, 5, 240)    2160        block4a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, 5, 5, 240)    960         block4a_dwconv[0][0]
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, 5, 5, 240)    0           block4a_bn[0][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 240)          0           block4a_activation[0][0]
# __________________________________________________________________________________________________
# block4a_se_reshape (Reshape)    (None, 1, 1, 240)    0           block4a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4a_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block4a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4a_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block4a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4a_se_excite (Multiply)    (None, 5, 5, 240)    0           block4a_activation[0][0]
#                                                                  block4a_se_expand[0][0]
# __________________________________________________________________________________________________
# block4a_project_conv (Conv2D)   (None, 5, 5, 80)     19200       block4a_se_excite[0][0]
# __________________________________________________________________________________________________
# block4a_project_bn (BatchNormal (None, 5, 5, 80)     320         block4a_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_conv (Conv2D)    (None, 5, 5, 480)    38400       block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_expand_bn (BatchNormali (None, 5, 5, 480)    1920        block4b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_activation (Acti (None, 5, 5, 480)    0           block4b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4b_dwconv (DepthwiseConv2D (None, 5, 5, 480)    4320        block4b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4b_bn (BatchNormalization) (None, 5, 5, 480)    1920        block4b_dwconv[0][0]
# __________________________________________________________________________________________________
# block4b_activation (Activation) (None, 5, 5, 480)    0           block4b_bn[0][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze (GlobalAvera (None, 480)          0           block4b_activation[0][0]
# __________________________________________________________________________________________________
# block4b_se_reshape (Reshape)    (None, 1, 1, 480)    0           block4b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4b_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block4b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4b_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block4b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4b_se_excite (Multiply)    (None, 5, 5, 480)    0           block4b_activation[0][0]
#                                                                  block4b_se_expand[0][0]
# __________________________________________________________________________________________________
# block4b_project_conv (Conv2D)   (None, 5, 5, 80)     38400       block4b_se_excite[0][0]
# __________________________________________________________________________________________________
# block4b_project_bn (BatchNormal (None, 5, 5, 80)     320         block4b_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_drop (FixedDropout)     (None, 5, 5, 80)     0           block4b_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_add (Add)               (None, 5, 5, 80)     0           block4b_drop[0][0]
#                                                                  block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_expand_conv (Conv2D)    (None, 5, 5, 480)    38400       block4b_add[0][0]
# __________________________________________________________________________________________________
# block4c_expand_bn (BatchNormali (None, 5, 5, 480)    1920        block4c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4c_expand_activation (Acti (None, 5, 5, 480)    0           block4c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4c_dwconv (DepthwiseConv2D (None, 5, 5, 480)    4320        block4c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4c_bn (BatchNormalization) (None, 5, 5, 480)    1920        block4c_dwconv[0][0]
# __________________________________________________________________________________________________
# block4c_activation (Activation) (None, 5, 5, 480)    0           block4c_bn[0][0]
# __________________________________________________________________________________________________
# block4c_se_squeeze (GlobalAvera (None, 480)          0           block4c_activation[0][0]
# __________________________________________________________________________________________________
# block4c_se_reshape (Reshape)    (None, 1, 1, 480)    0           block4c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4c_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block4c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4c_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block4c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4c_se_excite (Multiply)    (None, 5, 5, 480)    0           block4c_activation[0][0]
#                                                                  block4c_se_expand[0][0]
# __________________________________________________________________________________________________
# block4c_project_conv (Conv2D)   (None, 5, 5, 80)     38400       block4c_se_excite[0][0]
# __________________________________________________________________________________________________
# block4c_project_bn (BatchNormal (None, 5, 5, 80)     320         block4c_project_conv[0][0]
# __________________________________________________________________________________________________
# block4c_drop (FixedDropout)     (None, 5, 5, 80)     0           block4c_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_add (Add)               (None, 5, 5, 80)     0           block4c_drop[0][0]
#                                                                  block4b_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_conv (Conv2D)    (None, 5, 5, 480)    38400       block4c_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_bn (BatchNormali (None, 5, 5, 480)    1920        block5a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5a_expand_activation (Acti (None, 5, 5, 480)    0           block5a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5a_dwconv (DepthwiseConv2D (None, 5, 5, 480)    12000       block5a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5a_bn (BatchNormalization) (None, 5, 5, 480)    1920        block5a_dwconv[0][0]
# __________________________________________________________________________________________________
# block5a_activation (Activation) (None, 5, 5, 480)    0           block5a_bn[0][0]
# __________________________________________________________________________________________________
# block5a_se_squeeze (GlobalAvera (None, 480)          0           block5a_activation[0][0]
# __________________________________________________________________________________________________
# block5a_se_reshape (Reshape)    (None, 1, 1, 480)    0           block5a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5a_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block5a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5a_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block5a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5a_se_excite (Multiply)    (None, 5, 5, 480)    0           block5a_activation[0][0]
#                                                                  block5a_se_expand[0][0]
# __________________________________________________________________________________________________
# block5a_project_conv (Conv2D)   (None, 5, 5, 112)    53760       block5a_se_excite[0][0]
# __________________________________________________________________________________________________
# block5a_project_bn (BatchNormal (None, 5, 5, 112)    448         block5a_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_conv (Conv2D)    (None, 5, 5, 672)    75264       block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_expand_bn (BatchNormali (None, 5, 5, 672)    2688        block5b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_activation (Acti (None, 5, 5, 672)    0           block5b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5b_dwconv (DepthwiseConv2D (None, 5, 5, 672)    16800       block5b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5b_bn (BatchNormalization) (None, 5, 5, 672)    2688        block5b_dwconv[0][0]
# __________________________________________________________________________________________________
# block5b_activation (Activation) (None, 5, 5, 672)    0           block5b_bn[0][0]
# __________________________________________________________________________________________________
# block5b_se_squeeze (GlobalAvera (None, 672)          0           block5b_activation[0][0]
# __________________________________________________________________________________________________
# block5b_se_reshape (Reshape)    (None, 1, 1, 672)    0           block5b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5b_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block5b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5b_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block5b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5b_se_excite (Multiply)    (None, 5, 5, 672)    0           block5b_activation[0][0]
#                                                                  block5b_se_expand[0][0]
# __________________________________________________________________________________________________
# block5b_project_conv (Conv2D)   (None, 5, 5, 112)    75264       block5b_se_excite[0][0]
# __________________________________________________________________________________________________
# block5b_project_bn (BatchNormal (None, 5, 5, 112)    448         block5b_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_drop (FixedDropout)     (None, 5, 5, 112)    0           block5b_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_add (Add)               (None, 5, 5, 112)    0           block5b_drop[0][0]
#                                                                  block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_expand_conv (Conv2D)    (None, 5, 5, 672)    75264       block5b_add[0][0]
# __________________________________________________________________________________________________
# block5c_expand_bn (BatchNormali (None, 5, 5, 672)    2688        block5c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5c_expand_activation (Acti (None, 5, 5, 672)    0           block5c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5c_dwconv (DepthwiseConv2D (None, 5, 5, 672)    16800       block5c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5c_bn (BatchNormalization) (None, 5, 5, 672)    2688        block5c_dwconv[0][0]
# __________________________________________________________________________________________________
# block5c_activation (Activation) (None, 5, 5, 672)    0           block5c_bn[0][0]
# __________________________________________________________________________________________________
# block5c_se_squeeze (GlobalAvera (None, 672)          0           block5c_activation[0][0]
# __________________________________________________________________________________________________
# block5c_se_reshape (Reshape)    (None, 1, 1, 672)    0           block5c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5c_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block5c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5c_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block5c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5c_se_excite (Multiply)    (None, 5, 5, 672)    0           block5c_activation[0][0]
#                                                                  block5c_se_expand[0][0]
# __________________________________________________________________________________________________
# block5c_project_conv (Conv2D)   (None, 5, 5, 112)    75264       block5c_se_excite[0][0]
# __________________________________________________________________________________________________
# block5c_project_bn (BatchNormal (None, 5, 5, 112)    448         block5c_project_conv[0][0]
# __________________________________________________________________________________________________
# block5c_drop (FixedDropout)     (None, 5, 5, 112)    0           block5c_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_add (Add)               (None, 5, 5, 112)    0           block5c_drop[0][0]
#                                                                  block5b_add[0][0]
# __________________________________________________________________________________________________
# block6a_expand_conv (Conv2D)    (None, 5, 5, 672)    75264       block5c_add[0][0]
# __________________________________________________________________________________________________
# block6a_expand_bn (BatchNormali (None, 5, 5, 672)    2688        block6a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6a_expand_activation (Acti (None, 5, 5, 672)    0           block6a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6a_dwconv (DepthwiseConv2D (None, 3, 3, 672)    16800       block6a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6a_bn (BatchNormalization) (None, 3, 3, 672)    2688        block6a_dwconv[0][0]
# __________________________________________________________________________________________________
# block6a_activation (Activation) (None, 3, 3, 672)    0           block6a_bn[0][0]
# __________________________________________________________________________________________________
# block6a_se_squeeze (GlobalAvera (None, 672)          0           block6a_activation[0][0]
# __________________________________________________________________________________________________
# block6a_se_reshape (Reshape)    (None, 1, 1, 672)    0           block6a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6a_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block6a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6a_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block6a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6a_se_excite (Multiply)    (None, 3, 3, 672)    0           block6a_activation[0][0]
#                                                                  block6a_se_expand[0][0]
# __________________________________________________________________________________________________
# block6a_project_conv (Conv2D)   (None, 3, 3, 192)    129024      block6a_se_excite[0][0]
# __________________________________________________________________________________________________
# block6a_project_bn (BatchNormal (None, 3, 3, 192)    768         block6a_project_conv[0][0]
# __________________________________________________________________________________________________
# block6b_expand_conv (Conv2D)    (None, 3, 3, 1152)   221184      block6a_project_bn[0][0]
# __________________________________________________________________________________________________
# block6b_expand_bn (BatchNormali (None, 3, 3, 1152)   4608        block6b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6b_expand_activation (Acti (None, 3, 3, 1152)   0           block6b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6b_dwconv (DepthwiseConv2D (None, 3, 3, 1152)   28800       block6b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6b_bn (BatchNormalization) (None, 3, 3, 1152)   4608        block6b_dwconv[0][0]
# __________________________________________________________________________________________________
# block6b_activation (Activation) (None, 3, 3, 1152)   0           block6b_bn[0][0]
# __________________________________________________________________________________________________
# block6b_se_squeeze (GlobalAvera (None, 1152)         0           block6b_activation[0][0]
# __________________________________________________________________________________________________
# block6b_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6b_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block6b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6b_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block6b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6b_se_excite (Multiply)    (None, 3, 3, 1152)   0           block6b_activation[0][0]
#                                                                  block6b_se_expand[0][0]
# __________________________________________________________________________________________________
# block6b_project_conv (Conv2D)   (None, 3, 3, 192)    221184      block6b_se_excite[0][0]
# __________________________________________________________________________________________________
# block6b_project_bn (BatchNormal (None, 3, 3, 192)    768         block6b_project_conv[0][0]
# __________________________________________________________________________________________________
# block6b_drop (FixedDropout)     (None, 3, 3, 192)    0           block6b_project_bn[0][0]
# __________________________________________________________________________________________________
# block6b_add (Add)               (None, 3, 3, 192)    0           block6b_drop[0][0]
#                                                                  block6a_project_bn[0][0]
# __________________________________________________________________________________________________
# block6c_expand_conv (Conv2D)    (None, 3, 3, 1152)   221184      block6b_add[0][0]
# __________________________________________________________________________________________________
# block6c_expand_bn (BatchNormali (None, 3, 3, 1152)   4608        block6c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6c_expand_activation (Acti (None, 3, 3, 1152)   0           block6c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6c_dwconv (DepthwiseConv2D (None, 3, 3, 1152)   28800       block6c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6c_bn (BatchNormalization) (None, 3, 3, 1152)   4608        block6c_dwconv[0][0]
# __________________________________________________________________________________________________
# block6c_activation (Activation) (None, 3, 3, 1152)   0           block6c_bn[0][0]
# __________________________________________________________________________________________________
# block6c_se_squeeze (GlobalAvera (None, 1152)         0           block6c_activation[0][0]
# __________________________________________________________________________________________________
# block6c_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6c_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block6c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6c_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block6c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6c_se_excite (Multiply)    (None, 3, 3, 1152)   0           block6c_activation[0][0]
#                                                                  block6c_se_expand[0][0]
# __________________________________________________________________________________________________
# block6c_project_conv (Conv2D)   (None, 3, 3, 192)    221184      block6c_se_excite[0][0]
# __________________________________________________________________________________________________
# block6c_project_bn (BatchNormal (None, 3, 3, 192)    768         block6c_project_conv[0][0]
# __________________________________________________________________________________________________
# block6c_drop (FixedDropout)     (None, 3, 3, 192)    0           block6c_project_bn[0][0]
# __________________________________________________________________________________________________
# block6c_add (Add)               (None, 3, 3, 192)    0           block6c_drop[0][0]
#                                                                  block6b_add[0][0]
# __________________________________________________________________________________________________
# block6d_expand_conv (Conv2D)    (None, 3, 3, 1152)   221184      block6c_add[0][0]
# __________________________________________________________________________________________________
# block6d_expand_bn (BatchNormali (None, 3, 3, 1152)   4608        block6d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6d_expand_activation (Acti (None, 3, 3, 1152)   0           block6d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6d_dwconv (DepthwiseConv2D (None, 3, 3, 1152)   28800       block6d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6d_bn (BatchNormalization) (None, 3, 3, 1152)   4608        block6d_dwconv[0][0]
# __________________________________________________________________________________________________
# block6d_activation (Activation) (None, 3, 3, 1152)   0           block6d_bn[0][0]
# __________________________________________________________________________________________________
# block6d_se_squeeze (GlobalAvera (None, 1152)         0           block6d_activation[0][0]
# __________________________________________________________________________________________________
# block6d_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6d_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block6d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6d_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block6d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6d_se_excite (Multiply)    (None, 3, 3, 1152)   0           block6d_activation[0][0]
#                                                                  block6d_se_expand[0][0]
# __________________________________________________________________________________________________
# block6d_project_conv (Conv2D)   (None, 3, 3, 192)    221184      block6d_se_excite[0][0]
# __________________________________________________________________________________________________
# block6d_project_bn (BatchNormal (None, 3, 3, 192)    768         block6d_project_conv[0][0]
# __________________________________________________________________________________________________
# block6d_drop (FixedDropout)     (None, 3, 3, 192)    0           block6d_project_bn[0][0]
# __________________________________________________________________________________________________
# block6d_add (Add)               (None, 3, 3, 192)    0           block6d_drop[0][0]
#                                                                  block6c_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_conv (Conv2D)    (None, 3, 3, 1152)   221184      block6d_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 3, 3, 1152)   4608        block7a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 3, 3, 1152)   0           block7a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7a_dwconv (DepthwiseConv2D (None, 3, 3, 1152)   10368       block7a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 3, 3, 1152)   4608        block7a_dwconv[0][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 3, 3, 1152)   0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 1152)         0           block7a_activation[0][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block7a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block7a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block7a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 3, 3, 1152)   0           block7a_activation[0][0]
#                                                                  block7a_se_expand[0][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 3, 3, 320)    368640      block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 3, 3, 320)    1280        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 3, 3, 1280)   409600      block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 3, 3, 1280)   5120        top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 3, 3, 1280)   0           top_bn[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 1280)         0           top_activation[0][0]
# __________________________________________________________________________________________________
# out_root (Dense)                (None, 168)          215208      lambda[0][0]
# __________________________________________________________________________________________________
# out_vowel (Dense)               (None, 11)           14091       lambda[0][0]
# __________________________________________________________________________________________________
# out_consonant (Dense)           (None, 7)            8967        lambda[0][0]
# ==================================================================================================
# Total params: 4,287,254
# Trainable params: 4,245,238
# Non-trainable params: 42,016
# __________________________________________________________________________________________________

# %% [markdown]
# ## Test performance of EfficientNet B3

# %%
epochs = 30

name      = f"EfficientNet B3"
model_path = f'Model/{name}/'
external_path = f'models/{name}/'

if not os.path.exists(model_path):
    os.makedirs(model_path)

loss_weights = [0.40, 0.30, 0.30]
model = create_model_eff(input_shape=(74, 74, 1), effnet='B3', loss_weights=loss_weights)

# train model
print(f"Start training of {name}...")
model = train(name = name, prep_path=prep_path, data_path=data_path,
                model_path=model_path, datagen_args = datagen_args,
                preprocess_args = preprocess_args, cross_val_parts = cross_val_parts,
                cross_val_num = cross_val_num, epochs=epochs,
                webdav_client=client, min_epoch_upload=1, model=model,
                external_path=external_path)
# Out:
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (lambda_1), but
# are not present in its tracked objects:
#   <tf.Variable 'Variable:0' shape=() dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# Start training of EfficientNet B3...
# Performing data preprocessing...
# HBox(children=(IntProgress(value=0, description='Part 0', max=50210, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Part 1', max=50210, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Part 2', max=50210, style=ProgressStyle(description_width='in…
# HBox(children=(IntProgress(value=0, description='Part 3', max=50210, style=ProgressStyle(description_width='in…
# Converting grapheme_root to one-hot encoding
# Converting vowel_diacritic to one-hot encoding
# Converting consonant_diacritic to one-hot encoding
# Found 175735 validated image filenames.
# Found 25105 validated image filenames.
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/joeranbosma/mlip" target="_blank">https://app.wandb.ai/joeranbosma/mlip</a><br/>
#                 Run page: <a href="https://app.wandb.ai/joeranbosma/mlip/runs/1ize5x0m" target="_blank">https://app.wandb.ai/joeranbosma/mlip/runs/1ize5x0m</a><br/>
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# 685/686 [============================>.] - ETA: 0s - loss: 2.8742 - out_root_loss: 4.7834 - out_vowel_loss: 1.9950 - out_consonant_loss: 1.2077 - out_root_acc: 0.0309 - out_vowel_acc: 0.2739 - out_consonant_acc: 0.6223WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 621s 906ms/step - loss: 2.8736 - out_root_loss: 4.7832 - out_vowel_loss: 1.9939 - out_consonant_loss: 1.2071 - out_root_acc: 0.0309 - out_vowel_acc: 0.2741 - out_consonant_acc: 0.6224 - val_loss: 2.4213 - val_out_root_loss: 4.4579 - val_out_vowel_loss: 1.1296 - val_out_consonant_loss: 0.9976 - val_out_root_acc: 0.0494 - val_out_vowel_acc: 0.6051 - val_out_consonant_acc: 0.6466
# Saving new best model, with val global accuracy of 0.337612 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 2/2
#  37/686 [>.............................] - ETA: 8:47 - loss: 2.4418 - out_root_loss: 4.4380 - out_vowel_loss: 1.2089 - out_consonant_loss: 1.0132 - out_root_acc: 0.0536 - out_vowel_acc: 0.5671 - out_consonant_acc: 0.6415Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 1.9049 - out_root_loss: 3.5871 - out_vowel_loss: 0.8220 - out_consonant_loss: 0.7450 - out_root_acc: 0.1471 - out_vowel_acc: 0.7096 - out_consonant_acc: 0.7304WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 596s 869ms/step - loss: 1.9041 - out_root_loss: 3.5855 - out_vowel_loss: 0.8216 - out_consonant_loss: 0.7447 - out_root_acc: 0.1473 - out_vowel_acc: 0.7097 - out_consonant_acc: 0.7306 - val_loss: 1.2389 - val_out_root_loss: 2.4017 - val_out_vowel_loss: 0.4731 - val_out_consonant_loss: 0.4541 - val_out_root_acc: 0.3430 - val_out_vowel_acc: 0.8413 - val_out_consonant_acc: 0.8383
# Saving new best model, with val global accuracy of 0.591279 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 3/3
#  37/686 [>.............................] - ETA: 8:50 - loss: 1.3105 - out_root_loss: 2.4818 - out_vowel_loss: 0.5516 - out_consonant_loss: 0.5075 - out_root_acc: 0.3233 - out_vowel_acc: 0.8064 - out_consonant_acc: 0.8186Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 1.0001 - out_root_loss: 1.8683 - out_vowel_loss: 0.4488 - out_consonant_loss: 0.3939 - out_root_acc: 0.4723 - out_vowel_acc: 0.8472 - out_consonant_acc: 0.8621WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 596s 869ms/step - loss: 0.9998 - out_root_loss: 1.8677 - out_vowel_loss: 0.4487 - out_consonant_loss: 0.3937 - out_root_acc: 0.4724 - out_vowel_acc: 0.8472 - out_consonant_acc: 0.8621 - val_loss: 1.1804 - val_out_root_loss: 2.1180 - val_out_vowel_loss: 0.6686 - val_out_consonant_loss: 0.4422 - val_out_root_acc: 0.4686 - val_out_vowel_acc: 0.7829 - val_out_consonant_acc: 0.8480
# Saving new best model, with val global accuracy of 0.641851 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 4/4
#  38/686 [>.............................] - ETA: 8:47 - loss: 0.7650 - out_root_loss: 1.4004 - out_vowel_loss: 0.3801 - out_consonant_loss: 0.3028 - out_root_acc: 0.5928 - out_vowel_acc: 0.8769 - out_consonant_acc: 0.8963Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.6475 - out_root_loss: 1.1669 - out_vowel_loss: 0.3264 - out_consonant_loss: 0.2761 - out_root_acc: 0.6582 - out_vowel_acc: 0.8921 - out_consonant_acc: 0.9065WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 595s 868ms/step - loss: 0.6474 - out_root_loss: 1.1667 - out_vowel_loss: 0.3263 - out_consonant_loss: 0.2762 - out_root_acc: 0.6583 - out_vowel_acc: 0.8922 - out_consonant_acc: 0.9065 - val_loss: 0.4960 - val_out_root_loss: 0.9208 - val_out_vowel_loss: 0.2158 - val_out_consonant_loss: 0.2098 - val_out_root_acc: 0.7217 - val_out_vowel_acc: 0.9328 - val_out_consonant_acc: 0.9315
# Saving new best model, with val global accuracy of 0.826610 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 5/5
#  38/686 [>.............................] - ETA: 8:47 - loss: 0.5464 - out_root_loss: 0.9666 - out_vowel_loss: 0.2919 - out_consonant_loss: 0.2408 - out_root_acc: 0.7126 - out_vowel_acc: 0.9064 - out_consonant_acc: 0.9162Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.4925 - out_root_loss: 0.8645 - out_vowel_loss: 0.2668 - out_consonant_loss: 0.2223 - out_root_acc: 0.7446 - out_vowel_acc: 0.9136 - out_consonant_acc: 0.9257WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 595s 868ms/step - loss: 0.4924 - out_root_loss: 0.8643 - out_vowel_loss: 0.2667 - out_consonant_loss: 0.2223 - out_root_acc: 0.7446 - out_vowel_acc: 0.9137 - out_consonant_acc: 0.9257 - val_loss: 0.4296 - val_out_root_loss: 0.8084 - val_out_vowel_loss: 0.1815 - val_out_consonant_loss: 0.1725 - val_out_root_acc: 0.7550 - val_out_vowel_acc: 0.9421 - val_out_consonant_acc: 0.9429
# Saving new best model, with val global accuracy of 0.848404 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 6/6
#  38/686 [>.............................] - ETA: 8:47 - loss: 0.4384 - out_root_loss: 0.7688 - out_vowel_loss: 0.2371 - out_consonant_loss: 0.1990 - out_root_acc: 0.7705 - out_vowel_acc: 0.9226 - out_consonant_acc: 0.9328Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.4162 - out_root_loss: 0.7202 - out_vowel_loss: 0.2302 - out_consonant_loss: 0.1967 - out_root_acc: 0.7852 - out_vowel_acc: 0.9269 - out_consonant_acc: 0.9342WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 595s 867ms/step - loss: 0.4161 - out_root_loss: 0.7201 - out_vowel_loss: 0.2302 - out_consonant_loss: 0.1967 - out_root_acc: 0.7853 - out_vowel_acc: 0.9269 - out_consonant_acc: 0.9342 - val_loss: 0.3193 - val_out_root_loss: 0.5651 - val_out_vowel_loss: 0.1591 - val_out_consonant_loss: 0.1516 - val_out_root_acc: 0.8298 - val_out_vowel_acc: 0.9514 - val_out_consonant_acc: 0.9503
# Saving new best model, with val global accuracy of 0.890127 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 7/7
#  38/686 [>.............................] - ETA: 8:47 - loss: 0.3636 - out_root_loss: 0.6184 - out_vowel_loss: 0.2069 - out_consonant_loss: 0.1804 - out_root_acc: 0.8134 - out_vowel_acc: 0.9337 - out_consonant_acc: 0.9401Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.3725 - out_root_loss: 0.6362 - out_vowel_loss: 0.2139 - out_consonant_loss: 0.1794 - out_root_acc: 0.8101 - out_vowel_acc: 0.9323 - out_consonant_acc: 0.9401WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 596s 869ms/step - loss: 0.3724 - out_root_loss: 0.6361 - out_vowel_loss: 0.2138 - out_consonant_loss: 0.1794 - out_root_acc: 0.8101 - out_vowel_acc: 0.9324 - out_consonant_acc: 0.9401 - val_loss: 0.3788 - val_out_root_loss: 0.6752 - val_out_vowel_loss: 0.1992 - val_out_consonant_loss: 0.1630 - val_out_root_acc: 0.8113 - val_out_vowel_acc: 0.9437 - val_out_consonant_acc: 0.9499
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 8/8
# 685/686 [============================>.] - ETA: 0s - loss: 0.3454 - out_root_loss: 0.5885 - out_vowel_loss: 0.1980 - out_consonant_loss: 0.1685 - out_root_acc: 0.8254 - out_vowel_acc: 0.9376 - out_consonant_acc: 0.9448WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 596s 869ms/step - loss: 0.3452 - out_root_loss: 0.5883 - out_vowel_loss: 0.1979 - out_consonant_loss: 0.1685 - out_root_acc: 0.8254 - out_vowel_acc: 0.9376 - out_consonant_acc: 0.9448 - val_loss: 0.2606 - val_out_root_loss: 0.4664 - val_out_vowel_loss: 0.1236 - val_out_consonant_loss: 0.1230 - val_out_root_acc: 0.8602 - val_out_vowel_acc: 0.9669 - val_out_consonant_acc: 0.9606
# Saving new best model, with val global accuracy of 0.911880 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 9/9
#  38/686 [>.............................] - ETA: 8:47 - loss: 0.3373 - out_root_loss: 0.5833 - out_vowel_loss: 0.1863 - out_consonant_loss: 0.1602 - out_root_acc: 0.8257 - out_vowel_acc: 0.9414 - out_consonant_acc: 0.9460Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.3284 - out_root_loss: 0.5536 - out_vowel_loss: 0.1953 - out_consonant_loss: 0.1611 - out_root_acc: 0.8341 - out_vowel_acc: 0.9381 - out_consonant_acc: 0.9476WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 596s 869ms/step - loss: 0.3283 - out_root_loss: 0.5534 - out_vowel_loss: 0.1954 - out_consonant_loss: 0.1611 - out_root_acc: 0.8342 - out_vowel_acc: 0.9382 - out_consonant_acc: 0.9475 - val_loss: 0.2595 - val_out_root_loss: 0.4673 - val_out_vowel_loss: 0.1234 - val_out_consonant_loss: 0.1186 - val_out_root_acc: 0.8604 - val_out_vowel_acc: 0.9646 - val_out_consonant_acc: 0.9621
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 10/10
# 685/686 [============================>.] - ETA: 0s - loss: 0.2964 - out_root_loss: 0.4956 - out_vowel_loss: 0.1801 - out_consonant_loss: 0.1470 - out_root_acc: 0.8509 - out_vowel_acc: 0.9434 - out_consonant_acc: 0.9522WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 595s 867ms/step - loss: 0.2963 - out_root_loss: 0.4956 - out_vowel_loss: 0.1801 - out_consonant_loss: 0.1469 - out_root_acc: 0.8509 - out_vowel_acc: 0.9434 - out_consonant_acc: 0.9522 - val_loss: 0.2034 - val_out_root_loss: 0.3567 - val_out_vowel_loss: 0.1032 - val_out_consonant_loss: 0.0991 - val_out_root_acc: 0.8940 - val_out_vowel_acc: 0.9710 - val_out_consonant_acc: 0.9689
# Saving new best model, with val global accuracy of 0.931760 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 11/11
#  38/686 [>.............................] - ETA: 8:47 - loss: 0.2521 - out_root_loss: 0.4239 - out_vowel_loss: 0.1497 - out_consonant_loss: 0.1254 - out_root_acc: 0.8716 - out_vowel_acc: 0.9542 - out_consonant_acc: 0.9593Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.2871 - out_root_loss: 0.4791 - out_vowel_loss: 0.1752 - out_consonant_loss: 0.1429 - out_root_acc: 0.8563 - out_vowel_acc: 0.9456 - out_consonant_acc: 0.9534WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 595s 868ms/step - loss: 0.2871 - out_root_loss: 0.4791 - out_vowel_loss: 0.1752 - out_consonant_loss: 0.1429 - out_root_acc: 0.8563 - out_vowel_acc: 0.9456 - out_consonant_acc: 0.9534 - val_loss: 0.2881 - val_out_root_loss: 0.5061 - val_out_vowel_loss: 0.1482 - val_out_consonant_loss: 0.1372 - val_out_root_acc: 0.8478 - val_out_vowel_acc: 0.9563 - val_out_consonant_acc: 0.9561
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 12/12
# 685/686 [============================>.] - ETA: 0s - loss: 0.3102 - out_root_loss: 0.5188 - out_vowel_loss: 0.1892 - out_consonant_loss: 0.1531 - out_root_acc: 0.8438 - out_vowel_acc: 0.9403 - out_consonant_acc: 0.9498WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 595s 868ms/step - loss: 0.3101 - out_root_loss: 0.5187 - out_vowel_loss: 0.1891 - out_consonant_loss: 0.1531 - out_root_acc: 0.8438 - out_vowel_acc: 0.9403 - out_consonant_acc: 0.9498 - val_loss: 0.2475 - val_out_root_loss: 0.4415 - val_out_vowel_loss: 0.1232 - val_out_consonant_loss: 0.1130 - val_out_root_acc: 0.8686 - val_out_vowel_acc: 0.9642 - val_out_consonant_acc: 0.9649
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 13/13
# 685/686 [============================>.] - ETA: 0s - loss: 0.2927 - out_root_loss: 0.4872 - out_vowel_loss: 0.1784 - out_consonant_loss: 0.1477 - out_root_acc: 0.8535 - out_vowel_acc: 0.9433 - out_consonant_acc: 0.9513WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 596s 868ms/step - loss: 0.2927 - out_root_loss: 0.4870 - out_vowel_loss: 0.1785 - out_consonant_loss: 0.1478 - out_root_acc: 0.8536 - out_vowel_acc: 0.9432 - out_consonant_acc: 0.9513 - val_loss: 0.2378 - val_out_root_loss: 0.4249 - val_out_vowel_loss: 0.1187 - val_out_consonant_loss: 0.1074 - val_out_root_acc: 0.8723 - val_out_vowel_acc: 0.9670 - val_out_consonant_acc: 0.9674
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 14/14
# 685/686 [============================>.] - ETA: 0s - loss: 0.2694 - out_root_loss: 0.4475 - out_vowel_loss: 0.1645 - out_consonant_loss: 0.1369 - out_root_acc: 0.8643 - out_vowel_acc: 0.9485 - out_consonant_acc: 0.9548WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 596s 868ms/step - loss: 0.2693 - out_root_loss: 0.4473 - out_vowel_loss: 0.1645 - out_consonant_loss: 0.1368 - out_root_acc: 0.8643 - out_vowel_acc: 0.9485 - out_consonant_acc: 0.9548 - val_loss: 0.2052 - val_out_root_loss: 0.3613 - val_out_vowel_loss: 0.1026 - val_out_consonant_loss: 0.0996 - val_out_root_acc: 0.8917 - val_out_vowel_acc: 0.9702 - val_out_consonant_acc: 0.9688
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 15/15
# 685/686 [============================>.] - ETA: 0s - loss: 0.2787 - out_root_loss: 0.4638 - out_vowel_loss: 0.1714 - out_consonant_loss: 0.1393 - out_root_acc: 0.8596 - out_vowel_acc: 0.9455 - out_consonant_acc: 0.9549WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 595s 868ms/step - loss: 0.2786 - out_root_loss: 0.4636 - out_vowel_loss: 0.1714 - out_consonant_loss: 0.1393 - out_root_acc: 0.8597 - out_vowel_acc: 0.9455 - out_consonant_acc: 0.9549 - val_loss: 0.2311 - val_out_root_loss: 0.4072 - val_out_vowel_loss: 0.1231 - val_out_consonant_loss: 0.1042 - val_out_root_acc: 0.8803 - val_out_vowel_acc: 0.9634 - val_out_consonant_acc: 0.9680
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 16/16
# 685/686 [============================>.] - ETA: 0s - loss: 0.2511 - out_root_loss: 0.4149 - out_vowel_loss: 0.1555 - out_consonant_loss: 0.1282 - out_root_acc: 0.8747 - out_vowel_acc: 0.9516 - out_consonant_acc: 0.9582WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 596s 869ms/step - loss: 0.2511 - out_root_loss: 0.4150 - out_vowel_loss: 0.1555 - out_consonant_loss: 0.1282 - out_root_acc: 0.8747 - out_vowel_acc: 0.9515 - out_consonant_acc: 0.9582 - val_loss: 0.2234 - val_out_root_loss: 0.3823 - val_out_vowel_loss: 0.1224 - val_out_consonant_loss: 0.1127 - val_out_root_acc: 0.8881 - val_out_vowel_acc: 0.9643 - val_out_consonant_acc: 0.9660
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 17/17
# 685/686 [============================>.] - ETA: 0s - loss: 0.2673 - out_root_loss: 0.4426 - out_vowel_loss: 0.1636 - out_consonant_loss: 0.1375 - out_root_acc: 0.8656 - out_vowel_acc: 0.9488 - out_consonant_acc: 0.9547WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 595s 868ms/step - loss: 0.2673 - out_root_loss: 0.4425 - out_vowel_loss: 0.1635 - out_consonant_loss: 0.1374 - out_root_acc: 0.8657 - out_vowel_acc: 0.9488 - out_consonant_acc: 0.9547 - val_loss: 0.2236 - val_out_root_loss: 0.3902 - val_out_vowel_loss: 0.1166 - val_out_consonant_loss: 0.1085 - val_out_root_acc: 0.8814 - val_out_vowel_acc: 0.9674 - val_out_consonant_acc: 0.9661
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 18/18
# 685/686 [============================>.] - ETA: 0s - loss: 0.2432 - out_root_loss: 0.3989 - out_vowel_loss: 0.1546 - out_consonant_loss: 0.1241 - out_root_acc: 0.8786 - out_vowel_acc: 0.9523 - out_consonant_acc: 0.9598WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 595s 868ms/step - loss: 0.2431 - out_root_loss: 0.3989 - out_vowel_loss: 0.1546 - out_consonant_loss: 0.1241 - out_root_acc: 0.8787 - out_vowel_acc: 0.9524 - out_consonant_acc: 0.9598 - val_loss: 0.1849 - val_out_root_loss: 0.3200 - val_out_vowel_loss: 0.1052 - val_out_consonant_loss: 0.0844 - val_out_root_acc: 0.9014 - val_out_vowel_acc: 0.9718 - val_out_consonant_acc: 0.9745
# Saving new best model, with val global accuracy of 0.937191 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 19/19
#  37/686 [>.............................] - ETA: 8:49 - loss: 0.1994 - out_root_loss: 0.3292 - out_vowel_loss: 0.1290 - out_consonant_loss: 0.0968 - out_root_acc: 0.8965 - out_vowel_acc: 0.9608 - out_consonant_acc: 0.9665Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.2143 - out_root_loss: 0.3493 - out_vowel_loss: 0.1358 - out_consonant_loss: 0.1129 - out_root_acc: 0.8915 - out_vowel_acc: 0.9583 - out_consonant_acc: 0.9633WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 595s 868ms/step - loss: 0.2143 - out_root_loss: 0.3493 - out_vowel_loss: 0.1357 - out_consonant_loss: 0.1129 - out_root_acc: 0.8914 - out_vowel_acc: 0.9583 - out_consonant_acc: 0.9633 - val_loss: 0.1840 - val_out_root_loss: 0.3200 - val_out_vowel_loss: 0.0989 - val_out_consonant_loss: 0.0878 - val_out_root_acc: 0.9060 - val_out_vowel_acc: 0.9742 - val_out_consonant_acc: 0.9742
# Saving new best model, with val global accuracy of 0.940101 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 20/20
#  37/686 [>.............................] - ETA: 8:49 - loss: 0.1861 - out_root_loss: 0.2990 - out_vowel_loss: 0.1181 - out_consonant_loss: 0.1034 - out_root_acc: 0.9035 - out_vowel_acc: 0.9626 - out_consonant_acc: 0.9664Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.1920 - out_root_loss: 0.3096 - out_vowel_loss: 0.1229 - out_consonant_loss: 0.1042 - out_root_acc: 0.9037 - out_vowel_acc: 0.9623 - out_consonant_acc: 0.9663WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 596s 869ms/step - loss: 0.1919 - out_root_loss: 0.3094 - out_vowel_loss: 0.1230 - out_consonant_loss: 0.1042 - out_root_acc: 0.9037 - out_vowel_acc: 0.9623 - out_consonant_acc: 0.9663 - val_loss: 0.1855 - val_out_root_loss: 0.3292 - val_out_vowel_loss: 0.0937 - val_out_consonant_loss: 0.0858 - val_out_root_acc: 0.9008 - val_out_vowel_acc: 0.9742 - val_out_consonant_acc: 0.9742
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 21/21
# 685/686 [============================>.] - ETA: 0s - loss: 0.1761 - out_root_loss: 0.2805 - out_vowel_loss: 0.1150 - out_consonant_loss: 0.0980 - out_root_acc: 0.9122 - out_vowel_acc: 0.9644 - out_consonant_acc: 0.9678WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 596s 869ms/step - loss: 0.1760 - out_root_loss: 0.2805 - out_vowel_loss: 0.1149 - out_consonant_loss: 0.0979 - out_root_acc: 0.9122 - out_vowel_acc: 0.9644 - out_consonant_acc: 0.9678 - val_loss: 0.1792 - val_out_root_loss: 0.3160 - val_out_vowel_loss: 0.0924 - val_out_consonant_loss: 0.0835 - val_out_root_acc: 0.9068 - val_out_vowel_acc: 0.9740 - val_out_consonant_acc: 0.9752
# Saving new best model, with val global accuracy of 0.940579 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 22/22
#  37/686 [>.............................] - ETA: 8:50 - loss: 0.1894 - out_root_loss: 0.2979 - out_vowel_loss: 0.1262 - out_consonant_loss: 0.1079 - out_root_acc: 0.9031 - out_vowel_acc: 0.9596 - out_consonant_acc: 0.9653Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.1667 - out_root_loss: 0.2650 - out_vowel_loss: 0.1101 - out_consonant_loss: 0.0924 - out_root_acc: 0.9166 - out_vowel_acc: 0.9656 - out_consonant_acc: 0.9704WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 597s 870ms/step - loss: 0.1667 - out_root_loss: 0.2649 - out_vowel_loss: 0.1101 - out_consonant_loss: 0.0924 - out_root_acc: 0.9166 - out_vowel_acc: 0.9656 - out_consonant_acc: 0.9704 - val_loss: 0.1806 - val_out_root_loss: 0.3169 - val_out_vowel_loss: 0.0923 - val_out_consonant_loss: 0.0872 - val_out_root_acc: 0.9054 - val_out_vowel_acc: 0.9744 - val_out_consonant_acc: 0.9744
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 23/23
# 685/686 [============================>.] - ETA: 0s - loss: 0.1603 - out_root_loss: 0.2550 - out_vowel_loss: 0.1067 - out_consonant_loss: 0.0877 - out_root_acc: 0.9191 - out_vowel_acc: 0.9676 - out_consonant_acc: 0.9719WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 595s 867ms/step - loss: 0.1603 - out_root_loss: 0.2550 - out_vowel_loss: 0.1067 - out_consonant_loss: 0.0877 - out_root_acc: 0.9191 - out_vowel_acc: 0.9676 - out_consonant_acc: 0.9719 - val_loss: 0.1603 - val_out_root_loss: 0.2752 - val_out_vowel_loss: 0.0834 - val_out_consonant_loss: 0.0839 - val_out_root_acc: 0.9188 - val_out_vowel_acc: 0.9770 - val_out_consonant_acc: 0.9754
# Saving new best model, with val global accuracy of 0.947495 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 24/24
#  37/686 [>.............................] - ETA: 8:48 - loss: 0.1519 - out_root_loss: 0.2405 - out_vowel_loss: 0.0987 - out_consonant_loss: 0.0871 - out_root_acc: 0.9217 - out_vowel_acc: 0.9695 - out_consonant_acc: 0.9724Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.1579 - out_root_loss: 0.2502 - out_vowel_loss: 0.1057 - out_consonant_loss: 0.0871 - out_root_acc: 0.9202 - out_vowel_acc: 0.9675 - out_consonant_acc: 0.9718WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 596s 869ms/step - loss: 0.1579 - out_root_loss: 0.2500 - out_vowel_loss: 0.1057 - out_consonant_loss: 0.0871 - out_root_acc: 0.9202 - out_vowel_acc: 0.9675 - out_consonant_acc: 0.9718 - val_loss: 0.1648 - val_out_root_loss: 0.2841 - val_out_vowel_loss: 0.0935 - val_out_consonant_loss: 0.0769 - val_out_root_acc: 0.9178 - val_out_vowel_acc: 0.9749 - val_out_consonant_acc: 0.9772
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 25/25
# 685/686 [============================>.] - ETA: 0s - loss: 0.1448 - out_root_loss: 0.2291 - out_vowel_loss: 0.0967 - out_consonant_loss: 0.0806 - out_root_acc: 0.9269 - out_vowel_acc: 0.9703 - out_consonant_acc: 0.9739WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 596s 869ms/step - loss: 0.1448 - out_root_loss: 0.2290 - out_vowel_loss: 0.0966 - out_consonant_loss: 0.0805 - out_root_acc: 0.9269 - out_vowel_acc: 0.9703 - out_consonant_acc: 0.9739 - val_loss: 0.1654 - val_out_root_loss: 0.2939 - val_out_vowel_loss: 0.0834 - val_out_consonant_loss: 0.0759 - val_out_root_acc: 0.9143 - val_out_vowel_acc: 0.9773 - val_out_consonant_acc: 0.9773
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 26/26
# 685/686 [============================>.] - ETA: 0s - loss: 0.1440 - out_root_loss: 0.2277 - out_vowel_loss: 0.0961 - out_consonant_loss: 0.0804 - out_root_acc: 0.9270 - out_vowel_acc: 0.9705 - out_consonant_acc: 0.9737WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 596s 869ms/step - loss: 0.1440 - out_root_loss: 0.2277 - out_vowel_loss: 0.0961 - out_consonant_loss: 0.0804 - out_root_acc: 0.9270 - out_vowel_acc: 0.9705 - out_consonant_acc: 0.9737 - val_loss: 0.1595 - val_out_root_loss: 0.2731 - val_out_vowel_loss: 0.0904 - val_out_consonant_loss: 0.0772 - val_out_root_acc: 0.9197 - val_out_vowel_acc: 0.9758 - val_out_consonant_acc: 0.9774
# Saving new best model, with val global accuracy of 0.948113 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 27/27
#  37/686 [>.............................] - ETA: 8:50 - loss: 0.1359 - out_root_loss: 0.2183 - out_vowel_loss: 0.0865 - out_consonant_loss: 0.0754 - out_root_acc: 0.9283 - out_vowel_acc: 0.9723 - out_consonant_acc: 0.9743Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.1457 - out_root_loss: 0.2319 - out_vowel_loss: 0.0969 - out_consonant_loss: 0.0795 - out_root_acc: 0.9257 - out_vowel_acc: 0.9700 - out_consonant_acc: 0.9741WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 596s 869ms/step - loss: 0.1456 - out_root_loss: 0.2318 - out_vowel_loss: 0.0969 - out_consonant_loss: 0.0794 - out_root_acc: 0.9257 - out_vowel_acc: 0.9700 - out_consonant_acc: 0.9741 - val_loss: 0.1513 - val_out_root_loss: 0.2620 - val_out_vowel_loss: 0.0808 - val_out_consonant_loss: 0.0742 - val_out_root_acc: 0.9231 - val_out_vowel_acc: 0.9786 - val_out_consonant_acc: 0.9790
# Saving new best model, with val global accuracy of 0.950953 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 28/28
#  38/686 [>.............................] - ETA: 8:48 - loss: 0.1231 - out_root_loss: 0.1899 - out_vowel_loss: 0.0908 - out_consonant_loss: 0.0663 - out_root_acc: 0.9377 - out_vowel_acc: 0.9713 - out_consonant_acc: 0.9768Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.1274 - out_root_loss: 0.1984 - out_vowel_loss: 0.0877 - out_consonant_loss: 0.0726 - out_root_acc: 0.9361 - out_vowel_acc: 0.9729 - out_consonant_acc: 0.9768WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 596s 869ms/step - loss: 0.1274 - out_root_loss: 0.1983 - out_vowel_loss: 0.0876 - out_consonant_loss: 0.0725 - out_root_acc: 0.9361 - out_vowel_acc: 0.9729 - out_consonant_acc: 0.9768 - val_loss: 0.1442 - val_out_root_loss: 0.2500 - val_out_vowel_loss: 0.0785 - val_out_consonant_loss: 0.0689 - val_out_root_acc: 0.9277 - val_out_vowel_acc: 0.9796 - val_out_consonant_acc: 0.9808
# Saving new best model, with val global accuracy of 0.953862 to model-best.h5
# Uploading async...
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 29/29
#  38/686 [>.............................] - ETA: 8:47 - loss: 0.1196 - out_root_loss: 0.1846 - out_vowel_loss: 0.0827 - out_consonant_loss: 0.0696 - out_root_acc: 0.9414 - out_vowel_acc: 0.9734 - out_consonant_acc: 0.9775Upload finished.
# 685/686 [============================>.] - ETA: 0s - loss: 0.1235 - out_root_loss: 0.1917 - out_vowel_loss: 0.0866 - out_consonant_loss: 0.0695 - out_root_acc: 0.9383 - out_vowel_acc: 0.9731 - out_consonant_acc: 0.9776WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 596s 868ms/step - loss: 0.1235 - out_root_loss: 0.1917 - out_vowel_loss: 0.0866 - out_consonant_loss: 0.0695 - out_root_acc: 0.9383 - out_vowel_acc: 0.9731 - out_consonant_acc: 0.9776 - val_loss: 0.1560 - val_out_root_loss: 0.2717 - val_out_vowel_loss: 0.0831 - val_out_consonant_loss: 0.0748 - val_out_root_acc: 0.9223 - val_out_vowel_acc: 0.9786 - val_out_consonant_acc: 0.9795
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# Train for 686 steps, validate for 98 steps
# Epoch 30/30
# 685/686 [============================>.] - ETA: 0s - loss: 0.1181 - out_root_loss: 0.1840 - out_vowel_loss: 0.0816 - out_consonant_loss: 0.0669 - out_root_acc: 0.9411 - out_vowel_acc: 0.9750 - out_consonant_acc: 0.9788WARNING:tensorflow:sample_weight modes were coerced from
#   {'out_root': '...', 'out_vowel': '...', 'out_consonant': '...'}
#     to
#   ['...', '...', '...']
# 686/686 [==============================] - 596s 869ms/step - loss: 0.1181 - out_root_loss: 0.1839 - out_vowel_loss: 0.0817 - out_consonant_loss: 0.0668 - out_root_acc: 0.9411 - out_vowel_acc: 0.9750 - out_consonant_acc: 0.9787 - val_loss: 0.1535 - val_out_root_loss: 0.2682 - val_out_vowel_loss: 0.0800 - val_out_consonant_loss: 0.0742 - val_out_root_acc: 0.9242 - val_out_vowel_acc: 0.9792 - val_out_consonant_acc: 0.9795

# %%
1
# Out:
# 1

# %% [markdown]
# # Use pretrained imagenet
# Imagenet has 3 channels, bengali 1. Add a Conv layer with three filter to learn this transition. If stacking the images would have been best, this layer should learn ones in the middle and zeros elsewhere.
#
# **NOTE: IMPLEMENTATION NOT FINISHED!!**

# %%
# Create Model
def create_model_pretrained(input_shape = (74, 74, 1)):
    # Input Layer
    inp = Input(shape = input_shape)
    
    # Transition layer
    effnet_input = Conv2D(3, kernel_size=(3, 3))(inp)

    # Create and Compile Model and show Summary
    # x_model = efn.EfficientNetB0(weights = 'imagenet', include_top = False, input_tensor = effnet_input, pooling = None, classes = None)
    x_model = efn.EfficientNetB3(weights='imagenet', include_top=False, input_shape=(72, 72, 3),
                                 pooling=None, classes=None)
    
    # UnFreeze all layers
    for layer in x_model.layers:
        layer.trainable = True
    
    # GeM
    lambda_layer = Lambda(generalized_mean_pool_2d)
    lambda_layer.trainable_weights.extend([gm_exp])
    x = lambda_layer(x_model.output)
    
    # multi output
    grapheme_root = Dense(168, activation = 'softmax', name = 'out_root')(x)
    vowel_diacritic = Dense(11, activation = 'softmax', name = 'out_vowel')(x)
    consonant_diacritic = Dense(7, activation = 'softmax', name = 'out_consonant')(x)

    # model
    model = Model(inputs = x_model.input, outputs = [grapheme_root, vowel_diacritic, consonant_diacritic])

    return model

model = create_model_pretrained()
# Out:
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b3_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 44113920/44107200 [==============================] - 0s 0us/step

# %%
input_shape = (74, 74, 1)
inp = Input(shape = input_shape)

# Transition layer
effnet_input = Conv2D(3, kernel_size=(3, 3))(inp)
