# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/bengaliai-cv19/train.csv
# /kaggle/input/bengaliai-cv19/train_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/class_map.csv
# /kaggle/input/bengaliai-cv19/train_image_data_3.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_2.parquet
# /kaggle/input/bengaliai-cv19/train_image_data_1.parquet
# /kaggle/input/bengaliai-cv19/test_image_data_0.parquet
# /kaggle/input/bengaliai-cv19/test.csv
# /kaggle/input/bengaliai-cv19/train_image_data_0.parquet
# /kaggle/input/bengaliai-cv19/sample_submission.csv
# /kaggle/input/bengaliai-cv19/test_image_data_3.parquet

# %%
# !pip install wandb --upgrade
# Out:
# Collecting wandb
#   Downloading wandb-0.8.28-py2.py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 8.9 MB/s
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /opt/conda/lib/python3.6/site-packages (from wandb) (2.8.1)
# Requirement already satisfied, skipping upgrade: PyYAML>=3.10 in /opt/conda/lib/python3.6/site-packages (from wandb) (5.3)
# Requirement already satisfied, skipping upgrade: subprocess32>=3.5.3 in /opt/conda/lib/python3.6/site-packages (from wandb) (3.5.4)
# Requirement already satisfied, skipping upgrade: configparser>=3.8.1 in /opt/conda/lib/python3.6/site-packages (from wandb) (4.0.2)
# Requirement already satisfied, skipping upgrade: Click>=7.0 in /opt/conda/lib/python3.6/site-packages (from wandb) (7.0)
# Requirement already satisfied, skipping upgrade: watchdog>=0.8.3 in /opt/conda/lib/python3.6/site-packages (from wandb) (0.10.2)
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /opt/conda/lib/python3.6/site-packages (from wandb) (1.14.0)
# Requirement already satisfied, skipping upgrade: psutil>=5.0.0 in /opt/conda/lib/python3.6/site-packages (from wandb) (5.6.7)
# Requirement already satisfied, skipping upgrade: gql==0.2.0 in /opt/conda/lib/python3.6/site-packages (from wandb) (0.2.0)
# Requirement already satisfied, skipping upgrade: sentry-sdk>=0.4.0 in /opt/conda/lib/python3.6/site-packages (from wandb) (0.14.1)
# Requirement already satisfied, skipping upgrade: nvidia-ml-py3>=7.352.0 in /opt/conda/lib/python3.6/site-packages (from wandb) (7.352.0)
# Requirement already satisfied, skipping upgrade: GitPython>=1.0.0 in /opt/conda/lib/python3.6/site-packages (from wandb) (3.0.7)
# Requirement already satisfied, skipping upgrade: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.6/site-packages (from wandb) (0.4.0)
# Requirement already satisfied, skipping upgrade: requests>=2.0.0 in /opt/conda/lib/python3.6/site-packages (from wandb) (2.22.0)
# Requirement already satisfied, skipping upgrade: shortuuid>=0.5.0 in /opt/conda/lib/python3.6/site-packages (from wandb) (0.5.0)
# Requirement already satisfied, skipping upgrade: pathtools>=0.1.1 in /opt/conda/lib/python3.6/site-packages (from watchdog>=0.8.3->wandb) (0.1.2)
# Requirement already satisfied, skipping upgrade: promise<3,>=2.0 in /opt/conda/lib/python3.6/site-packages (from gql==0.2.0->wandb) (2.3)
# Requirement already satisfied, skipping upgrade: graphql-core<2,>=0.5.0 in /opt/conda/lib/python3.6/site-packages (from gql==0.2.0->wandb) (1.1)
# Requirement already satisfied, skipping upgrade: certifi in /opt/conda/lib/python3.6/site-packages (from sentry-sdk>=0.4.0->wandb) (2019.11.28)
# Requirement already satisfied, skipping upgrade: urllib3>=1.10.0 in /opt/conda/lib/python3.6/site-packages (from sentry-sdk>=0.4.0->wandb) (1.25.8)
# Requirement already satisfied, skipping upgrade: gitdb2>=2.0.0 in /opt/conda/lib/python3.6/site-packages (from GitPython>=1.0.0->wandb) (2.0.6)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests>=2.0.0->wandb) (2.8)
# Requirement already satisfied, skipping upgrade: smmap2>=2.0.0 in /opt/conda/lib/python3.6/site-packages (from gitdb2>=2.0.0->GitPython>=1.0.0->wandb) (2.0.5)
# Installing collected packages: wandb
#   Attempting uninstall: wandb
#     Found existing installation: wandb 0.8.27
#     Uninstalling wandb-0.8.27:
#       Successfully uninstalled wandb-0.8.27
# Successfully installed wandb-0.8.28

# %%
# !wandb login ***REMOVED***
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Successfully logged in to Weights & Biases!

# %%
# !pip install webdavclient3
# Out:
# Collecting webdavclient3
#   Downloading webdavclient3-3.14.tar.gz (27 kB)
# Requirement already satisfied: requests in /opt/conda/lib/python3.6/site-packages (from webdavclient3) (2.22.0)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.6/site-packages (from webdavclient3) (4.5.0)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.6/site-packages (from webdavclient3) (2.8.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests->webdavclient3) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests->webdavclient3) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests->webdavclient3) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests->webdavclient3) (1.25.8)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.6/site-packages (from python-dateutil->webdavclient3) (1.14.0)
# Building wheels for collected packages: webdavclient3
# done
#   Created wheel for webdavclient3: filename=webdavclient3-3.14-py3-none-any.whl size=27166 sha256=647241fd430ac5d8cf9501e27da5c4cda97d203014f91566dc646619e1d4a925
#   Stored in directory: /root/.cache/pip/wheels/70/b9/51/4a84e36476c1f6469e0d41d0b9c7341ecea7421762d685d1a0
# Successfully built webdavclient3
# Installing collected packages: webdavclient3
# Successfully installed webdavclient3-3.14

# %%
from webdav3.client import Client
from kaggle_secrets import UserSecretsClient

options = {
 'webdav_hostname': "https://joeranbosma.stackstorage.com/remote.php/webdav",
 'webdav_login':    "MLiP",
 'webdav_password': UserSecretsClient().get_secret("webdav_pass")
}
client = Client(options)

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from starter_eda_model_funcs import MultiOutputDataGenerator
from helper import to_one_hot, preview_data_aug
from preprocessing import perform_preprocessing
from flow_kaggle import generators_from_prep, generator_wrapper, train

# Load adapted model
from model_test_feature_selection import get_model_feature_training

# further settings
FIG_DIR = 'results/generated_figs/'
plt.rcParams["figure.figsize"] = (10, 4.5) # set higher on 4k monitor
plt.rcParams["savefig.format"] = "pdf"
plt.rcParams["savefig.dpi"] = 400
plt.rcParams["savefig.transparent"] = True
plt.rcParams.update({'font.size': 16})
plt.rcParams["savefig.bbox"] = 'tight'

# %%
datagen_args = dict(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    zca_whitening=False,  # apply ZCA whitening
    rotation_range=8,  # randomly rotate images in the range (degrees, 0 to 180)
    zoom_range = 0.15, # Randomly zoom image 
    width_shift_range=0.15,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.15,  # randomly shift images vertically (fraction of total height)
    horizontal_flip=False,  # randomly flip images
    vertical_flip=False,
    shear_range=8, #Shear Intensity (Shear angle in counter-clockwise direction in degrees)
)

cross_val_parts = 8 # for 12.5% validation data and 87.5% train data
cross_val_num = 0 # which part (shuffled) from [0, ..., n-1]


# non-drop-out 32x32
roi_size = 32-10
padding_size = 5

preprocess_args = dict(
        image_width=roi_size_option + padding*2,
        image_height=roi_size + padding*2,
        padding=padding,
        cross_val_num=cross_val_num,
        cross_val_parts=cross_val_parts,
    )

model_name      = f"prep_{roi_size}_{padding}"
prep_path = f"/kaggle/working/prep/prep_{roi_size}_{padding}/"
model_path = f'/kaggle/working/models/{model_name}/'
external_path = f'models/{model_name}/'
    
if not os.path.exists(model_path):
    os.makedirs(model_path)

# define model
model_32_no_max_pool= get_model_feature_training(False,img_size = 32, loss_weights=[0.5, 0.25, 0.25])

# TODO: ensure model_name refers to adapted model
# train model
print(f"Start training of {model_name}...")
model = train(model = model_32_no_max_pool, name = model_name, prep_path=prep_path, data_path='/kaggle/input/bengaliai-cv19/',
              model_path=model_path, datagen_args = datagen_args,
              preprocess_args = preprocess_args, cross_val_parts = cross_val_parts,
              cross_val_num = cross_val_num, epochs=30, webdav_client=client,
              external_path=external_path)
    
# TODO: move this till end?
# clean up
shutil.rmtree(prep_path)
# Out:
# Start training of prep_96_5...
# Performing data preprocessing...
# Part 0: 100%|██████████| 50210/50210 [00:48<00:00, 1043.00it/s]
# Part 1: 100%|██████████| 50210/50210 [00:58<00:00, 854.40it/s]
# Part 2: 100%|██████████| 50210/50210 [01:12<00:00, 696.63it/s]
# Part 3: 100%|██████████| 50210/50210 [00:58<00:00, 853.30it/s]
# Converting grapheme_root to one-hot encoding
# Converting vowel_diacritic to one-hot encoding
# Converting consonant_diacritic to one-hot encoding
# Found 175735 validated image filenames.
# Found 25105 validated image filenames.
# Creating directory in WebDAV client: models/prep_96_5//
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/joeranbosma/mlip" target="_blank">https://app.wandb.ai/joeranbosma/mlip</a><br/>
#                 Run page: <a href="https://app.wandb.ai/joeranbosma/mlip/runs/w26kkxhb" target="_blank">https://app.wandb.ai/joeranbosma/mlip/runs/w26kkxhb</a><br/>
# Train for 686 steps, validate for 98 steps
# 686/686 [==============================] - 379s 552ms/step - loss: 2.4821 - out_root_loss: 3.9793 - out_vowel_loss: 1.0559 - out_consonant_loss: 0.9138 - out_root_acc: 0.0946 - out_vowel_acc: 0.6288 - out_consonant_acc: 0.6877 - val_loss: 1.4916 - val_out_root_loss: 2.4795 - val_out_vowel_loss: 0.5025 - val_out_consonant_loss: 0.5050 - val_out_root_acc: 0.3045 - val_out_vowel_acc: 0.8296 - val_out_consonant_acc: 0.8182
# Train for 686 steps, validate for 98 steps
# Epoch 2/2
# 686/686 [==============================] - 357s 521ms/step - loss: 1.0994 - out_root_loss: 1.7461 - out_vowel_loss: 0.5077 - out_consonant_loss: 0.3976 - out_root_acc: 0.5066 - out_vowel_acc: 0.8300 - out_consonant_acc: 0.8650 - val_loss: 0.4296 - val_out_root_loss: 0.6641 - val_out_vowel_loss: 0.2059 - val_out_consonant_loss: 0.1843 - val_out_root_acc: 0.8054 - val_out_vowel_acc: 0.9383 - val_out_consonant_acc: 0.9437
# Train for 686 steps, validate for 98 steps
# Epoch 3/3
# 686/686 [==============================] - 355s 517ms/step - loss: 0.5482 - out_root_loss: 0.8234 - out_vowel_loss: 0.3101 - out_consonant_loss: 0.2359 - out_root_acc: 0.7661 - out_vowel_acc: 0.9031 - out_consonant_acc: 0.9244 - val_loss: 0.2750 - val_out_root_loss: 0.4306 - val_out_vowel_loss: 0.1223 - val_out_consonant_loss: 0.1164 - val_out_root_acc: 0.8782 - val_out_vowel_acc: 0.9652 - val_out_consonant_acc: 0.9647
# Train for 686 steps, validate for 98 steps
# Epoch 4/4
# 686/686 [==============================] - 354s 516ms/step - loss: 0.3998 - out_root_loss: 0.5905 - out_vowel_loss: 0.2352 - out_consonant_loss: 0.1832 - out_root_acc: 0.8356 - out_vowel_acc: 0.9290 - out_consonant_acc: 0.9426 - val_loss: 0.2318 - val_out_root_loss: 0.3585 - val_out_vowel_loss: 0.1101 - val_out_consonant_loss: 0.1001 - val_out_root_acc: 0.9033 - val_out_vowel_acc: 0.9699 - val_out_consonant_acc: 0.9722
# Train for 686 steps, validate for 98 steps
# Epoch 5/5
# 686/686 [==============================] - 357s 520ms/step - loss: 0.3303 - out_root_loss: 0.4847 - out_vowel_loss: 0.1951 - out_consonant_loss: 0.1566 - out_root_acc: 0.8648 - out_vowel_acc: 0.9424 - out_consonant_acc: 0.9521 - val_loss: 0.1951 - val_out_root_loss: 0.2937 - val_out_vowel_loss: 0.0983 - val_out_consonant_loss: 0.0945 - val_out_root_acc: 0.9193 - val_out_vowel_acc: 0.9731 - val_out_consonant_acc: 0.9727
# Train for 686 steps, validate for 98 steps
# Epoch 6/6
# 686/686 [==============================] - 344s 502ms/step - loss: 0.2905 - out_root_loss: 0.4234 - out_vowel_loss: 0.1764 - out_consonant_loss: 0.1387 - out_root_acc: 0.8827 - out_vowel_acc: 0.9498 - out_consonant_acc: 0.9577 - val_loss: 0.1839 - val_out_root_loss: 0.2780 - val_out_vowel_loss: 0.0938 - val_out_consonant_loss: 0.0859 - val_out_root_acc: 0.9247 - val_out_vowel_acc: 0.9748 - val_out_consonant_acc: 0.9759
# Train for 686 steps, validate for 98 steps
# Epoch 7/7
# 686/686 [==============================] - 338s 492ms/step - loss: 0.2613 - out_root_loss: 0.3790 - out_vowel_loss: 0.1581 - out_consonant_loss: 0.1289 - out_root_acc: 0.8940 - out_vowel_acc: 0.9553 - out_consonant_acc: 0.9614 - val_loss: 0.1772 - val_out_root_loss: 0.2723 - val_out_vowel_loss: 0.0841 - val_out_consonant_loss: 0.0801 - val_out_root_acc: 0.9277 - val_out_vowel_acc: 0.9779 - val_out_consonant_acc: 0.9778
# Train for 686 steps, validate for 98 steps
# Epoch 8/8
# 686/686 [==============================] - 336s 490ms/step - loss: 0.2420 - out_root_loss: 0.3504 - out_vowel_loss: 0.1491 - out_consonant_loss: 0.1181 - out_root_acc: 0.9023 - out_vowel_acc: 0.9579 - out_consonant_acc: 0.9645 - val_loss: 0.1608 - val_out_root_loss: 0.2429 - val_out_vowel_loss: 0.0816 - val_out_consonant_loss: 0.0760 - val_out_root_acc: 0.9358 - val_out_vowel_acc: 0.9793 - val_out_consonant_acc: 0.9787
# Train for 686 steps, validate for 98 steps
# Epoch 9/9
# 686/686 [==============================] - 334s 487ms/step - loss: 0.2240 - out_root_loss: 0.3212 - out_vowel_loss: 0.1423 - out_consonant_loss: 0.1116 - out_root_acc: 0.9092 - out_vowel_acc: 0.9605 - out_consonant_acc: 0.9665 - val_loss: 0.1567 - val_out_root_loss: 0.2359 - val_out_vowel_loss: 0.0849 - val_out_consonant_loss: 0.0702 - val_out_root_acc: 0.9377 - val_out_vowel_acc: 0.9793 - val_out_consonant_acc: 0.9814
# Train for 686 steps, validate for 98 steps
# Epoch 10/10
# 686/686 [==============================] - 335s 489ms/step - loss: 0.2090 - out_root_loss: 0.2989 - out_vowel_loss: 0.1318 - out_consonant_loss: 0.1063 - out_root_acc: 0.9162 - out_vowel_acc: 0.9635 - out_consonant_acc: 0.9686 - val_loss: 0.1453 - val_out_root_loss: 0.2201 - val_out_vowel_loss: 0.0754 - val_out_consonant_loss: 0.0656 - val_out_root_acc: 0.9413 - val_out_vowel_acc: 0.9802 - val_out_consonant_acc: 0.9821
# Saving new best model, with val global accuracy of 0.961226 to model-best.h5
# Uploading async...
# Train for 686 steps, validate for 98 steps
# Epoch 11/11
#  78/686 [==>...........................] - ETA: 4:36 - loss: 0.1946 - out_root_loss: 0.2752 - out_vowel_loss: 0.1273 - out_consonant_loss: 0.1008 - out_root_acc: 0.9217 - out_vowel_acc: 0.9638 - out_consonant_acc: 0.9693Upload finished.
# 686/686 [==============================] - 335s 488ms/step - loss: 0.1997 - out_root_loss: 0.2854 - out_vowel_loss: 0.1267 - out_consonant_loss: 0.1013 - out_root_acc: 0.9194 - out_vowel_acc: 0.9648 - out_consonant_acc: 0.9700 - val_loss: 0.1446 - val_out_root_loss: 0.2228 - val_out_vowel_loss: 0.0682 - val_out_consonant_loss: 0.0645 - val_out_root_acc: 0.9404 - val_out_vowel_acc: 0.9833 - val_out_consonant_acc: 0.9827
# Saving new best model, with val global accuracy of 0.961779 to model-best.h5
# Uploading async...
# Train for 686 steps, validate for 98 steps
# Epoch 12/12
#  76/686 [==>...........................] - ETA: 4:44 - loss: 0.1787 - out_root_loss: 0.2505 - out_vowel_loss: 0.1206 - out_consonant_loss: 0.0933 - out_root_acc: 0.9288 - out_vowel_acc: 0.9670 - out_consonant_acc: 0.9709Upload finished.
# 686/686 [==============================] - 335s 489ms/step - loss: 0.1863 - out_root_loss: 0.2664 - out_vowel_loss: 0.1166 - out_consonant_loss: 0.0959 - out_root_acc: 0.9244 - out_vowel_acc: 0.9676 - out_consonant_acc: 0.9716 - val_loss: 0.1442 - val_out_root_loss: 0.2190 - val_out_vowel_loss: 0.0718 - val_out_consonant_loss: 0.0669 - val_out_root_acc: 0.9425 - val_out_vowel_acc: 0.9821 - val_out_consonant_acc: 0.9829
# Saving new best model, with val global accuracy of 0.962614 to model-best.h5
# Uploading async...
# Train for 686 steps, validate for 98 steps
# Epoch 13/13
#  78/686 [==>...........................] - ETA: 4:36 - loss: 0.1740 - out_root_loss: 0.2443 - out_vowel_loss: 0.1145 - out_consonant_loss: 0.0928 - out_root_acc: 0.9310 - out_vowel_acc: 0.9682 - out_consonant_acc: 0.9734Upload finished.
# 686/686 [==============================] - 333s 486ms/step - loss: 0.1775 - out_root_loss: 0.2520 - out_vowel_loss: 0.1142 - out_consonant_loss: 0.0919 - out_root_acc: 0.9289 - out_vowel_acc: 0.9684 - out_consonant_acc: 0.9731 - val_loss: 0.1439 - val_out_root_loss: 0.2193 - val_out_vowel_loss: 0.0752 - val_out_consonant_loss: 0.0617 - val_out_root_acc: 0.9428 - val_out_vowel_acc: 0.9813 - val_out_consonant_acc: 0.9838
# Saving new best model, with val global accuracy of 0.962795 to model-best.h5
# Uploading async...
# Train for 686 steps, validate for 98 steps
# Epoch 14/14
#  77/686 [==>...........................] - ETA: 4:41 - loss: 0.1681 - out_root_loss: 0.2369 - out_vowel_loss: 0.1136 - out_consonant_loss: 0.0849 - out_root_acc: 0.9323 - out_vowel_acc: 0.9686 - out_consonant_acc: 0.9750Upload finished.
# 686/686 [==============================] - 336s 490ms/step - loss: 0.1704 - out_root_loss: 0.2415 - out_vowel_loss: 0.1104 - out_consonant_loss: 0.0882 - out_root_acc: 0.9311 - out_vowel_acc: 0.9696 - out_consonant_acc: 0.9736 - val_loss: 0.1319 - val_out_root_loss: 0.1987 - val_out_vowel_loss: 0.0672 - val_out_consonant_loss: 0.0629 - val_out_root_acc: 0.9480 - val_out_vowel_acc: 0.9834 - val_out_consonant_acc: 0.9830
# Saving new best model, with val global accuracy of 0.965592 to model-best.h5
# Uploading async...
# Train for 686 steps, validate for 98 steps
# Epoch 15/15
#  77/686 [==>...........................] - ETA: 4:41 - loss: 0.1600 - out_root_loss: 0.2298 - out_vowel_loss: 0.0962 - out_consonant_loss: 0.0841 - out_root_acc: 0.9356 - out_vowel_acc: 0.9735 - out_consonant_acc: 0.9748Upload finished.
# 686/686 [==============================] - 336s 490ms/step - loss: 0.1619 - out_root_loss: 0.2295 - out_vowel_loss: 0.1048 - out_consonant_loss: 0.0837 - out_root_acc: 0.9348 - out_vowel_acc: 0.9712 - out_consonant_acc: 0.9754 - val_loss: 0.1354 - val_out_root_loss: 0.2039 - val_out_vowel_loss: 0.0692 - val_out_consonant_loss: 0.0645 - val_out_root_acc: 0.9468 - val_out_vowel_acc: 0.9840 - val_out_consonant_acc: 0.9824
# Train for 686 steps, validate for 98 steps
# Epoch 16/16
# 686/686 [==============================] - 335s 488ms/step - loss: 0.1562 - out_root_loss: 0.2206 - out_vowel_loss: 0.1017 - out_consonant_loss: 0.0819 - out_root_acc: 0.9370 - out_vowel_acc: 0.9719 - out_consonant_acc: 0.9756 - val_loss: 0.1380 - val_out_root_loss: 0.2110 - val_out_vowel_loss: 0.0656 - val_out_consonant_loss: 0.0645 - val_out_root_acc: 0.9449 - val_out_vowel_acc: 0.9837 - val_out_consonant_acc: 0.9828
# Train for 686 steps, validate for 98 steps
# Epoch 17/17
# 686/686 [==============================] - 336s 490ms/step - loss: 0.1496 - out_root_loss: 0.2103 - out_vowel_loss: 0.0988 - out_consonant_loss: 0.0792 - out_root_acc: 0.9395 - out_vowel_acc: 0.9731 - out_consonant_acc: 0.9768 - val_loss: 0.1287 - val_out_root_loss: 0.1945 - val_out_vowel_loss: 0.0618 - val_out_consonant_loss: 0.0641 - val_out_root_acc: 0.9503 - val_out_vowel_acc: 0.9854 - val_out_consonant_acc: 0.9821
# Saving new best model, with val global accuracy of 0.966960 to model-best.h5
# Uploading async...
# Train for 686 steps, validate for 98 steps
# Epoch 18/18
#  78/686 [==>...........................] - ETA: 4:37 - loss: 0.1376 - out_root_loss: 0.1912 - out_vowel_loss: 0.0949 - out_consonant_loss: 0.0732 - out_root_acc: 0.9432 - out_vowel_acc: 0.9749 - out_consonant_acc: 0.9787Upload finished.
# 686/686 [==============================] - 335s 489ms/step - loss: 0.1435 - out_root_loss: 0.2009 - out_vowel_loss: 0.0959 - out_consonant_loss: 0.0762 - out_root_acc: 0.9421 - out_vowel_acc: 0.9740 - out_consonant_acc: 0.9780 - val_loss: 0.1267 - val_out_root_loss: 0.1924 - val_out_vowel_loss: 0.0622 - val_out_consonant_loss: 0.0597 - val_out_root_acc: 0.9514 - val_out_vowel_acc: 0.9852 - val_out_consonant_acc: 0.9849
# Saving new best model, with val global accuracy of 0.968208 to model-best.h5
# Uploading async...
# Train for 686 steps, validate for 98 steps
# Epoch 19/19
#  76/686 [==>...........................] - ETA: 4:43 - loss: 0.1372 - out_root_loss: 0.1921 - out_vowel_loss: 0.0912 - out_consonant_loss: 0.0735 - out_root_acc: 0.9425 - out_vowel_acc: 0.9745 - out_consonant_acc: 0.9766Upload finished.
# 686/686 [==============================] - 337s 491ms/step - loss: 0.1308 - out_root_loss: 0.1815 - out_vowel_loss: 0.0887 - out_consonant_loss: 0.0714 - out_root_acc: 0.9473 - out_vowel_acc: 0.9759 - out_consonant_acc: 0.9787 - val_loss: 0.1203 - val_out_root_loss: 0.1834 - val_out_vowel_loss: 0.0585 - val_out_consonant_loss: 0.0562 - val_out_root_acc: 0.9529 - val_out_vowel_acc: 0.9857 - val_out_consonant_acc: 0.9854
# Saving new best model, with val global accuracy of 0.969375 to model-best.h5
# Uploading async...
# Train for 686 steps, validate for 98 steps
# Epoch 22/22
#  77/686 [==>...........................] - ETA: 4:41 - loss: 0.1214 - out_root_loss: 0.1674 - out_vowel_loss: 0.0849 - out_consonant_loss: 0.0660 - out_root_acc: 0.9509 - out_vowel_acc: 0.9769 - out_consonant_acc: 0.9797Upload finished.
# 686/686 [==============================] - 335s 489ms/step - loss: 0.1235 - out_root_loss: 0.1719 - out_vowel_loss: 0.0828 - out_consonant_loss: 0.0673 - out_root_acc: 0.9501 - out_vowel_acc: 0.9770 - out_consonant_acc: 0.9802 - val_loss: 0.1214 - val_out_root_loss: 0.1821 - val_out_vowel_loss: 0.0625 - val_out_consonant_loss: 0.0588 - val_out_root_acc: 0.9536 - val_out_vowel_acc: 0.9845 - val_out_consonant_acc: 0.9840
# Train for 686 steps, validate for 98 steps
# Epoch 24/24
# 686/686 [==============================] - 335s 488ms/step - loss: 0.1175 - out_root_loss: 0.1618 - out_vowel_loss: 0.0809 - out_consonant_loss: 0.0653 - out_root_acc: 0.9524 - out_vowel_acc: 0.9773 - out_consonant_acc: 0.9808 - val_loss: 0.1185 - val_out_root_loss: 0.1786 - val_out_vowel_loss: 0.0590 - val_out_consonant_loss: 0.0577 - val_out_root_acc: 0.9546 - val_out_vowel_acc: 0.9864 - val_out_consonant_acc: 0.9847
# Saving new best model, with val global accuracy of 0.970089 to model-best.h5
# Uploading async...
# Train for 686 steps, validate for 98 steps
# Epoch 25/25
#  77/686 [==>...........................] - ETA: 4:41 - loss: 0.1106 - out_root_loss: 0.1550 - out_vowel_loss: 0.0736 - out_consonant_loss: 0.0587 - out_root_acc: 0.9554 - out_vowel_acc: 0.9794 - out_consonant_acc: 0.9842Upload finished.
# 686/686 [==============================] - 335s 488ms/step - loss: 0.1158 - out_root_loss: 0.1591 - out_vowel_loss: 0.0810 - out_consonant_loss: 0.0642 - out_root_acc: 0.9532 - out_vowel_acc: 0.9775 - out_consonant_acc: 0.9813 - val_loss: 0.1263 - val_out_root_loss: 0.1902 - val_out_vowel_loss: 0.0625 - val_out_consonant_loss: 0.0624 - val_out_root_acc: 0.9520 - val_out_vowel_acc: 0.9843 - val_out_consonant_acc: 0.9839
# Train for 686 steps, validate for 98 steps
# Epoch 26/26
# 686/686 [==============================] - 334s 487ms/step - loss: 0.1159 - out_root_loss: 0.1598 - out_vowel_loss: 0.0795 - out_consonant_loss: 0.0644 - out_root_acc: 0.9534 - out_vowel_acc: 0.9778 - out_consonant_acc: 0.9810 - val_loss: 0.1168 - val_out_root_loss: 0.1760 - val_out_vowel_loss: 0.0599 - val_out_consonant_loss: 0.0554 - val_out_root_acc: 0.9565 - val_out_vowel_acc: 0.9861 - val_out_consonant_acc: 0.9855
# Saving new best model, with val global accuracy of 0.971156 to model-best.h5
# Uploading async...
# Train for 686 steps, validate for 98 steps
# Epoch 27/27
#  77/686 [==>...........................] - ETA: 4:41 - loss: 0.1060 - out_root_loss: 0.1428 - out_vowel_loss: 0.0772 - out_consonant_loss: 0.0611 - out_root_acc: 0.9577 - out_vowel_acc: 0.9791 - out_consonant_acc: 0.9820Upload finished.
# 686/686 [==============================] - 335s 488ms/step - loss: 0.1095 - out_root_loss: 0.1504 - out_vowel_loss: 0.0779 - out_consonant_loss: 0.0592 - out_root_acc: 0.9556 - out_vowel_acc: 0.9787 - out_consonant_acc: 0.9826 - val_loss: 0.1192 - val_out_root_loss: 0.1810 - val_out_vowel_loss: 0.0600 - val_out_consonant_loss: 0.0548 - val_out_root_acc: 0.9552 - val_out_vowel_acc: 0.9861 - val_out_consonant_acc: 0.9865
# Train for 686 steps, validate for 98 steps
# Epoch 28/28
# 686/686 [==============================] - 334s 487ms/step - loss: 0.1097 - out_root_loss: 0.1494 - out_vowel_loss: 0.0774 - out_consonant_loss: 0.0623 - out_root_acc: 0.9555 - out_vowel_acc: 0.9787 - out_consonant_acc: 0.9820 - val_loss: 0.1153 - val_out_root_loss: 0.1751 - val_out_vowel_loss: 0.0563 - val_out_consonant_loss: 0.0546 - val_out_root_acc: 0.9553 - val_out_vowel_acc: 0.9868 - val_out_consonant_acc: 0.9856
# Train for 686 steps, validate for 98 steps
# Epoch 29/29
# 686/686 [==============================] - 334s 487ms/step - loss: 0.1062 - out_root_loss: 0.1439 - out_vowel_loss: 0.0765 - out_consonant_loss: 0.0606 - out_root_acc: 0.9574 - out_vowel_acc: 0.9789 - out_consonant_acc: 0.9824 - val_loss: 0.1215 - val_out_root_loss: 0.1878 - val_out_vowel_loss: 0.0580 - val_out_consonant_loss: 0.0523 - val_out_root_acc: 0.9537 - val_out_vowel_acc: 0.9857 - val_out_consonant_acc: 0.9858
# Train for 686 steps, validate for 98 steps
# Epoch 30/30
# 686/686 [==============================] - 334s 487ms/step - loss: 0.1049 - out_root_loss: 0.1433 - out_vowel_loss: 0.0741 - out_consonant_loss: 0.0588 - out_root_acc: 0.9579 - out_vowel_acc: 0.9794 - out_consonant_acc: 0.9828 - val_loss: 0.1173 - val_out_root_loss: 0.1794 - val_out_vowel_loss: 0.0563 - val_out_consonant_loss: 0.0541 - val_out_root_acc: 0.9557 - val_out_vowel_acc: 0.9870 - val_out_consonant_acc: 0.9860
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-dbd8f07679bd> in <module>
#      45
#      46     # clean up
# ---> 47     shutil.rmtree(prep_path)
#
# NameError: name 'shutil' is not defined

# %%
# with pooling 64x64
roi_size = 64-10
padding_size = 5

preprocess_args = dict(
        image_width=roi_size_option + padding*2,
        image_height=roi_size + padding*2,
        padding=padding,
        cross_val_num=cross_val_num,
        cross_val_parts=cross_val_parts,
    )

model_name      = f"prep_{roi_size}_{padding}"
prep_path = f"/kaggle/working/prep/prep_{roi_size}_{padding}/"
model_path = f'/kaggle/working/models/{model_name}/'
external_path = f'models/{model_name}/'
    
if not os.path.exists(model_path):
    os.makedirs(model_path)

# define model
model_64_yes_max_pool= get_model_feature_training(True,img_size = 64, loss_weights=[0.5, 0.25, 0.25])

# TODO: ensure model_name refers to adapted model
# train model
print(f"Start training of {model_name}...")
model = train(model = model_64_yes_max_pool, name = model_name, prep_path=prep_path, data_path='/kaggle/input/bengaliai-cv19/',
              model_path=model_path, datagen_args = datagen_args,
              preprocess_args = preprocess_args, cross_val_parts = cross_val_parts,
              cross_val_num = cross_val_num, epochs=30, webdav_client=client,
              external_path=external_path)
    

# Keep preprocessing of 64 for next 64 without max pooling

# %%
roi_size = 64-10
padding_size = 5

preprocess_args = dict(
        image_width=roi_size_option + padding*2,
        image_height=roi_size + padding*2,
        padding=padding,
        cross_val_num=cross_val_num,
        cross_val_parts=cross_val_parts,
    )

model_name      = f"prep_{roi_size}_{padding}"
prep_path = f"/kaggle/working/prep/prep_{roi_size}_{padding}/"
model_path = f'/kaggle/working/models/{model_name}/'
external_path = f'models/{model_name}/'
    
if not os.path.exists(model_path):
    os.makedirs(model_path)

# define model
model_64_no_max_pool= get_model_feature_training(False,img_size = 64, loss_weights=[0.5, 0.25, 0.25])

# TODO: ensure model_name refers to adapted model
# train model
print(f"Start training of {model_name}...")
model = train(model = model_64_no_max_pool, name = model_name, prep_path=prep_path, data_path='/kaggle/input/bengaliai-cv19/',
              model_path=model_path, datagen_args = datagen_args,
              preprocess_args = preprocess_args, cross_val_parts = cross_val_parts,
              cross_val_num = cross_val_num, epochs=30, webdav_client=client,
              external_path=external_path)
    
# TODO: move this till end?
# clean up
shutil.rmtree(prep_path)

# %%
# with pooling 128x128
roi_size = 128-10
padding_size = 5

preprocess_args = dict(
        image_width=roi_size_option + padding*2,
        image_height=roi_size + padding*2,
        padding=padding,
        cross_val_num=cross_val_num,
        cross_val_parts=cross_val_parts,
    )

model_name      = f"prep_{roi_size}_{padding}"
prep_path = f"/kaggle/working/prep/prep_{roi_size}_{padding}/"
model_path = f'/kaggle/working/models/{model_name}/'
external_path = f'models/{model_name}/'
    
if not os.path.exists(model_path):
    os.makedirs(model_path)

# define model
model_128_yes_max_pool= get_model_feature_training(True,img_size = 128, loss_weights=[0.5, 0.25, 0.25])

# TODO: ensure model_name refers to adapted model
# train model
print(f"Start training of {model_name}...")
model = train(model = model_128_yes_max_pool, name = model_name, prep_path=prep_path, data_path='/kaggle/input/bengaliai-cv19/',
              model_path=model_path, datagen_args = datagen_args,
              preprocess_args = preprocess_args, cross_val_parts = cross_val_parts,
              cross_val_num = cross_val_num, epochs=30, webdav_client=client,
              external_path=external_path)
